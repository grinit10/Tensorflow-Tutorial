# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = 'ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})
# Out:
# C:\Users\Arnab\.conda\envs\tensorflow\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 6ms/step - loss: 257.9743 - y1_output_loss: 115.1045 - y2_output_loss: 142.8698 - y1_output_root_mean_squared_error: 10.7287 - y2_output_root_mean_squared_error: 11.9528 - val_loss: 38.0339 - val_y1_output_loss: 17.9453 - val_y2_output_loss: 20.0885 - val_y1_output_root_mean_squared_error: 4.2362 - val_y2_output_root_mean_squared_error: 4.4820
# Epoch 2/500
# 62/62 [==============================] - 0s 4ms/step - loss: 32.8146 - y1_output_loss: 12.4130 - y2_output_loss: 20.4016 - y1_output_root_mean_squared_error: 3.5232 - y2_output_root_mean_squared_error: 4.5168 - val_loss: 27.3161 - val_y1_output_loss: 12.9112 - val_y2_output_loss: 14.4050 - val_y1_output_root_mean_squared_error: 3.5932 - val_y2_output_root_mean_squared_error: 3.7954
# Epoch 3/500
# 62/62 [==============================] - 0s 4ms/step - loss: 31.7091 - y1_output_loss: 11.2387 - y2_output_loss: 20.4704 - y1_output_root_mean_squared_error: 3.3524 - y2_output_root_mean_squared_error: 4.5244 - val_loss: 62.8030 - val_y1_output_loss: 20.6664 - val_y2_output_loss: 42.1366 - val_y1_output_root_mean_squared_error: 4.5460 - val_y2_output_root_mean_squared_error: 6.4913
# Epoch 4/500
# 62/62 [==============================] - 0s 4ms/step - loss: 25.5627 - y1_output_loss: 9.2701 - y2_output_loss: 16.2926 - y1_output_root_mean_squared_error: 3.0447 - y2_output_root_mean_squared_error: 4.0364 - val_loss: 31.6652 - val_y1_output_loss: 13.0095 - val_y2_output_loss: 18.6556 - val_y1_output_root_mean_squared_error: 3.6069 - val_y2_output_root_mean_squared_error: 4.3192
# Epoch 5/500
# 62/62 [==============================] - 0s 3ms/step - loss: 24.9571 - y1_output_loss: 9.3395 - y2_output_loss: 15.6176 - y1_output_root_mean_squared_error: 3.0561 - y2_output_root_mean_squared_error: 3.9519 - val_loss: 31.1975 - val_y1_output_loss: 12.5281 - val_y2_output_loss: 18.6694 - val_y1_output_root_mean_squared_error: 3.5395 - val_y2_output_root_mean_squared_error: 4.3208
# Epoch 6/500
# 62/62 [==============================] - 0s 3ms/step - loss: 20.5096 - y1_output_loss: 8.0861 - y2_output_loss: 12.4235 - y1_output_root_mean_squared_error: 2.8436 - y2_output_root_mean_squared_error: 3.5247 - val_loss: 25.3775 - val_y1_output_loss: 11.0625 - val_y2_output_loss: 14.3150 - val_y1_output_root_mean_squared_error: 3.3260 - val_y2_output_root_mean_squared_error: 3.7835
# Epoch 7/500
# 62/62 [==============================] - 0s 3ms/step - loss: 21.4526 - y1_output_loss: 8.3619 - y2_output_loss: 13.0907 - y1_output_root_mean_squared_error: 2.8917 - y2_output_root_mean_squared_error: 3.6181 - val_loss: 26.5966 - val_y1_output_loss: 11.5557 - val_y2_output_loss: 15.0409 - val_y1_output_root_mean_squared_error: 3.3994 - val_y2_output_root_mean_squared_error: 3.8783
# Epoch 8/500
# 62/62 [==============================] - 0s 3ms/step - loss: 24.3926 - y1_output_loss: 8.7981 - y2_output_loss: 15.5945 - y1_output_root_mean_squared_error: 2.9662 - y2_output_root_mean_squared_error: 3.9490 - val_loss: 20.9248 - val_y1_output_loss: 10.0476 - val_y2_output_loss: 10.8773 - val_y1_output_root_mean_squared_error: 3.1698 - val_y2_output_root_mean_squared_error: 3.2981
# Epoch 9/500
# 62/62 [==============================] - 0s 3ms/step - loss: 20.4122 - y1_output_loss: 7.8688 - y2_output_loss: 12.5434 - y1_output_root_mean_squared_error: 2.8051 - y2_output_root_mean_squared_error: 3.5417 - val_loss: 20.1671 - val_y1_output_loss: 9.8558 - val_y2_output_loss: 10.3113 - val_y1_output_root_mean_squared_error: 3.1394 - val_y2_output_root_mean_squared_error: 3.2111
# Epoch 10/500
# 62/62 [==============================] - 0s 4ms/step - loss: 23.6928 - y1_output_loss: 8.2951 - y2_output_loss: 15.3977 - y1_output_root_mean_squared_error: 2.8801 - y2_output_root_mean_squared_error: 3.9240 - val_loss: 22.3969 - val_y1_output_loss: 10.6919 - val_y2_output_loss: 11.7050 - val_y1_output_root_mean_squared_error: 3.2698 - val_y2_output_root_mean_squared_error: 3.4213
# Epoch 11/500
# 62/62 [==============================] - 0s 4ms/step - loss: 22.4180 - y1_output_loss: 8.4763 - y2_output_loss: 13.9416 - y1_output_root_mean_squared_error: 2.9114 - y2_output_root_mean_squared_error: 3.7339 - val_loss: 21.1389 - val_y1_output_loss: 9.4916 - val_y2_output_loss: 11.6473 - val_y1_output_root_mean_squared_error: 3.0808 - val_y2_output_root_mean_squared_error: 3.4128
# Epoch 12/500
# 62/62 [==============================] - 0s 4ms/step - loss: 18.9352 - y1_output_loss: 7.5702 - y2_output_loss: 11.3650 - y1_output_root_mean_squared_error: 2.7514 - y2_output_root_mean_squared_error: 3.3712 - val_loss: 20.7724 - val_y1_output_loss: 10.1587 - val_y2_output_loss: 10.6137 - val_y1_output_root_mean_squared_error: 3.1873 - val_y2_output_root_mean_squared_error: 3.2579
# Epoch 13/500
# 62/62 [==============================] - 0s 4ms/step - loss: 22.5561 - y1_output_loss: 8.0414 - y2_output_loss: 14.5147 - y1_output_root_mean_squared_error: 2.8357 - y2_output_root_mean_squared_error: 3.8098 - val_loss: 28.1968 - val_y1_output_loss: 12.9235 - val_y2_output_loss: 15.2733 - val_y1_output_root_mean_squared_error: 3.5949 - val_y2_output_root_mean_squared_error: 3.9081
# Epoch 14/500
# 62/62 [==============================] - 0s 4ms/step - loss: 21.8367 - y1_output_loss: 8.1927 - y2_output_loss: 13.6440 - y1_output_root_mean_squared_error: 2.8623 - y2_output_root_mean_squared_error: 3.6938 - val_loss: 23.1708 - val_y1_output_loss: 9.9084 - val_y2_output_loss: 13.2624 - val_y1_output_root_mean_squared_error: 3.1478 - val_y2_output_root_mean_squared_error: 3.6418
# Epoch 15/500
# 62/62 [==============================] - 0s 4ms/step - loss: 18.7444 - y1_output_loss: 6.9956 - y2_output_loss: 11.7488 - y1_output_root_mean_squared_error: 2.6449 - y2_output_root_mean_squared_error: 3.4277 - val_loss: 20.1597 - val_y1_output_loss: 9.5839 - val_y2_output_loss: 10.5758 - val_y1_output_root_mean_squared_error: 3.0958 - val_y2_output_root_mean_squared_error: 3.2521
# Epoch 16/500
# 62/62 [==============================] - 0s 4ms/step - loss: 19.7280 - y1_output_loss: 7.1534 - y2_output_loss: 12.5746 - y1_output_root_mean_squared_error: 2.6746 - y2_output_root_mean_squared_error: 3.5461 - val_loss: 18.9166 - val_y1_output_loss: 8.8774 - val_y2_output_loss: 10.0392 - val_y1_output_root_mean_squared_error: 2.9795 - val_y2_output_root_mean_squared_error: 3.1685
# Epoch 17/500
# 62/62 [==============================] - 0s 3ms/step - loss: 18.7310 - y1_output_loss: 7.1334 - y2_output_loss: 11.5976 - y1_output_root_mean_squared_error: 2.6709 - y2_output_root_mean_squared_error: 3.4055 - val_loss: 19.2721 - val_y1_output_loss: 8.6042 - val_y2_output_loss: 10.6679 - val_y1_output_root_mean_squared_error: 2.9333 - val_y2_output_root_mean_squared_error: 3.2662
# Epoch 18/500
# 62/62 [==============================] - 0s 3ms/step - loss: 19.9313 - y1_output_loss: 7.3632 - y2_output_loss: 12.5682 - y1_output_root_mean_squared_error: 2.7135 - y2_output_root_mean_squared_error: 3.5452 - val_loss: 23.2125 - val_y1_output_loss: 11.2982 - val_y2_output_loss: 11.9143 - val_y1_output_root_mean_squared_error: 3.3613 - val_y2_output_root_mean_squared_error: 3.4517
# Epoch 19/500
# 62/62 [==============================] - 0s 3ms/step - loss: 18.4822 - y1_output_loss: 6.7360 - y2_output_loss: 11.7463 - y1_output_root_mean_squared_error: 2.5954 - y2_output_root_mean_squared_error: 3.4273 - val_loss: 22.1819 - val_y1_output_loss: 9.0341 - val_y2_output_loss: 13.1478 - val_y1_output_root_mean_squared_error: 3.0057 - val_y2_output_root_mean_squared_error: 3.6260
# Epoch 20/500
# 62/62 [==============================] - 0s 4ms/step - loss: 15.6070 - y1_output_loss: 6.2608 - y2_output_loss: 9.3463 - y1_output_root_mean_squared_error: 2.5021 - y2_output_root_mean_squared_error: 3.0572 - val_loss: 18.2108 - val_y1_output_loss: 8.7975 - val_y2_output_loss: 9.4133 - val_y1_output_root_mean_squared_error: 2.9661 - val_y2_output_root_mean_squared_error: 3.0681
# Epoch 21/500
# 62/62 [==============================] - 0s 4ms/step - loss: 15.1320 - y1_output_loss: 5.9858 - y2_output_loss: 9.1462 - y1_output_root_mean_squared_error: 2.4466 - y2_output_root_mean_squared_error: 3.0243 - val_loss: 15.6691 - val_y1_output_loss: 7.1911 - val_y2_output_loss: 8.4779 - val_y1_output_root_mean_squared_error: 2.6816 - val_y2_output_root_mean_squared_error: 2.9117
# Epoch 22/500
# 62/62 [==============================] - 0s 3ms/step - loss: 14.5204 - y1_output_loss: 5.8330 - y2_output_loss: 8.6874 - y1_output_root_mean_squared_error: 2.4152 - y2_output_root_mean_squared_error: 2.9474 - val_loss: 16.1855 - val_y1_output_loss: 7.3176 - val_y2_output_loss: 8.8679 - val_y1_output_root_mean_squared_error: 2.7051 - val_y2_output_root_mean_squared_error: 2.9779
# Epoch 23/500
# 62/62 [==============================] - 0s 3ms/step - loss: 15.6944 - y1_output_loss: 5.8590 - y2_output_loss: 9.8354 - y1_output_root_mean_squared_error: 2.4205 - y2_output_root_mean_squared_error: 3.1361 - val_loss: 20.3449 - val_y1_output_loss: 8.3321 - val_y2_output_loss: 12.0128 - val_y1_output_root_mean_squared_error: 2.8865 - val_y2_output_root_mean_squared_error: 3.4659
# Epoch 24/500
# 62/62 [==============================] - 0s 3ms/step - loss: 17.7214 - y1_output_loss: 6.2461 - y2_output_loss: 11.4753 - y1_output_root_mean_squared_error: 2.4992 - y2_output_root_mean_squared_error: 3.3875 - val_loss: 15.0162 - val_y1_output_loss: 6.6321 - val_y2_output_loss: 8.3841 - val_y1_output_root_mean_squared_error: 2.5753 - val_y2_output_root_mean_squared_error: 2.8955
# Epoch 25/500
# 62/62 [==============================] - 0s 4ms/step - loss: 14.7099 - y1_output_loss: 5.6139 - y2_output_loss: 9.0960 - y1_output_root_mean_squared_error: 2.3694 - y2_output_root_mean_squared_error: 3.0160 - val_loss: 24.5110 - val_y1_output_loss: 8.0070 - val_y2_output_loss: 16.5041 - val_y1_output_root_mean_squared_error: 2.8297 - val_y2_output_root_mean_squared_error: 4.0625
# Epoch 26/500
# 62/62 [==============================] - 0s 3ms/step - loss: 14.1160 - y1_output_loss: 5.3662 - y2_output_loss: 8.7498 - y1_output_root_mean_squared_error: 2.3165 - y2_output_root_mean_squared_error: 2.9580 - val_loss: 15.7960 - val_y1_output_loss: 6.4553 - val_y2_output_loss: 9.3407 - val_y1_output_root_mean_squared_error: 2.5407 - val_y2_output_root_mean_squared_error: 3.0563
# Epoch 27/500
# 62/62 [==============================] - 0s 3ms/step - loss: 16.3975 - y1_output_loss: 6.0186 - y2_output_loss: 10.3789 - y1_output_root_mean_squared_error: 2.4533 - y2_output_root_mean_squared_error: 3.2216 - val_loss: 26.9116 - val_y1_output_loss: 8.0110 - val_y2_output_loss: 18.9006 - val_y1_output_root_mean_squared_error: 2.8304 - val_y2_output_root_mean_squared_error: 4.3475
# Epoch 28/500
# 62/62 [==============================] - 0s 4ms/step - loss: 12.1782 - y1_output_loss: 4.8986 - y2_output_loss: 7.2796 - y1_output_root_mean_squared_error: 2.2133 - y2_output_root_mean_squared_error: 2.6981 - val_loss: 15.0373 - val_y1_output_loss: 6.4374 - val_y2_output_loss: 8.5999 - val_y1_output_root_mean_squared_error: 2.5372 - val_y2_output_root_mean_squared_error: 2.9326
# Epoch 29/500
# 62/62 [==============================] - 0s 4ms/step - loss: 13.3546 - y1_output_loss: 5.1194 - y2_output_loss: 8.2352 - y1_output_root_mean_squared_error: 2.2626 - y2_output_root_mean_squared_error: 2.8697 - val_loss: 16.7176 - val_y1_output_loss: 6.4954 - val_y2_output_loss: 10.2222 - val_y1_output_root_mean_squared_error: 2.5486 - val_y2_output_root_mean_squared_error: 3.1972
# Epoch 30/500
# 62/62 [==============================] - 0s 4ms/step - loss: 14.0221 - y1_output_loss: 5.1200 - y2_output_loss: 8.9021 - y1_output_root_mean_squared_error: 2.2627 - y2_output_root_mean_squared_error: 2.9836 - val_loss: 40.5536 - val_y1_output_loss: 11.9420 - val_y2_output_loss: 28.6117 - val_y1_output_root_mean_squared_error: 3.4557 - val_y2_output_root_mean_squared_error: 5.3490
# Epoch 31/500
# 62/62 [==============================] - 0s 3ms/step - loss: 13.0803 - y1_output_loss: 4.9866 - y2_output_loss: 8.0937 - y1_output_root_mean_squared_error: 2.2331 - y2_output_root_mean_squared_error: 2.8449 - val_loss: 15.3854 - val_y1_output_loss: 6.4825 - val_y2_output_loss: 8.9029 - val_y1_output_root_mean_squared_error: 2.5461 - val_y2_output_root_mean_squared_error: 2.9838
# Epoch 32/500
# 62/62 [==============================] - 0s 4ms/step - loss: 13.1609 - y1_output_loss: 4.7935 - y2_output_loss: 8.3674 - y1_output_root_mean_squared_error: 2.1894 - y2_output_root_mean_squared_error: 2.8926 - val_loss: 12.4342 - val_y1_output_loss: 5.3866 - val_y2_output_loss: 7.0476 - val_y1_output_root_mean_squared_error: 2.3209 - val_y2_output_root_mean_squared_error: 2.6547
# Epoch 33/500
# 62/62 [==============================] - 0s 4ms/step - loss: 14.1517 - y1_output_loss: 5.1617 - y2_output_loss: 8.9900 - y1_output_root_mean_squared_error: 2.2719 - y2_output_root_mean_squared_error: 2.9983 - val_loss: 14.2123 - val_y1_output_loss: 6.3119 - val_y2_output_loss: 7.9005 - val_y1_output_root_mean_squared_error: 2.5123 - val_y2_output_root_mean_squared_error: 2.8108
# Epoch 34/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.9268 - y1_output_loss: 4.3795 - y2_output_loss: 6.5472 - y1_output_root_mean_squared_error: 2.0927 - y2_output_root_mean_squared_error: 2.5588 - val_loss: 26.7474 - val_y1_output_loss: 7.9452 - val_y2_output_loss: 18.8022 - val_y1_output_root_mean_squared_error: 2.8187 - val_y2_output_root_mean_squared_error: 4.3361
# Epoch 35/500
# 62/62 [==============================] - 0s 4ms/step - loss: 12.8974 - y1_output_loss: 4.7376 - y2_output_loss: 8.1598 - y1_output_root_mean_squared_error: 2.1766 - y2_output_root_mean_squared_error: 2.8565 - val_loss: 14.1475 - val_y1_output_loss: 4.7028 - val_y2_output_loss: 9.4447 - val_y1_output_root_mean_squared_error: 2.1686 - val_y2_output_root_mean_squared_error: 3.0732
# Epoch 36/500
# 62/62 [==============================] - 0s 4ms/step - loss: 11.0224 - y1_output_loss: 4.0488 - y2_output_loss: 6.9735 - y1_output_root_mean_squared_error: 2.0122 - y2_output_root_mean_squared_error: 2.6407 - val_loss: 20.3820 - val_y1_output_loss: 6.2432 - val_y2_output_loss: 14.1387 - val_y1_output_root_mean_squared_error: 2.4986 - val_y2_output_root_mean_squared_error: 3.7602
# Epoch 37/500
# 62/62 [==============================] - 0s 4ms/step - loss: 10.0786 - y1_output_loss: 3.8094 - y2_output_loss: 6.2691 - y1_output_root_mean_squared_error: 1.9518 - y2_output_root_mean_squared_error: 2.5038 - val_loss: 25.3032 - val_y1_output_loss: 5.8841 - val_y2_output_loss: 19.4191 - val_y1_output_root_mean_squared_error: 2.4257 - val_y2_output_root_mean_squared_error: 4.4067
# Epoch 38/500
# 62/62 [==============================] - 0s 4ms/step - loss: 10.9042 - y1_output_loss: 4.0097 - y2_output_loss: 6.8944 - y1_output_root_mean_squared_error: 2.0024 - y2_output_root_mean_squared_error: 2.6257 - val_loss: 23.3805 - val_y1_output_loss: 6.5216 - val_y2_output_loss: 16.8589 - val_y1_output_root_mean_squared_error: 2.5537 - val_y2_output_root_mean_squared_error: 4.1060
# Epoch 39/500
# 62/62 [==============================] - 0s 4ms/step - loss: 11.5892 - y1_output_loss: 4.2177 - y2_output_loss: 7.3715 - y1_output_root_mean_squared_error: 2.0537 - y2_output_root_mean_squared_error: 2.7151 - val_loss: 10.8939 - val_y1_output_loss: 4.3487 - val_y2_output_loss: 6.5452 - val_y1_output_root_mean_squared_error: 2.0853 - val_y2_output_root_mean_squared_error: 2.5584
# Epoch 40/500
# 62/62 [==============================] - 0s 4ms/step - loss: 10.4972 - y1_output_loss: 3.7530 - y2_output_loss: 6.7442 - y1_output_root_mean_squared_error: 1.9373 - y2_output_root_mean_squared_error: 2.5970 - val_loss: 23.7173 - val_y1_output_loss: 6.1790 - val_y2_output_loss: 17.5383 - val_y1_output_root_mean_squared_error: 2.4858 - val_y2_output_root_mean_squared_error: 4.1879
# Epoch 41/500
# 62/62 [==============================] - 0s 4ms/step - loss: 10.0998 - y1_output_loss: 3.6415 - y2_output_loss: 6.4583 - y1_output_root_mean_squared_error: 1.9083 - y2_output_root_mean_squared_error: 2.5413 - val_loss: 14.3573 - val_y1_output_loss: 5.4914 - val_y2_output_loss: 8.8659 - val_y1_output_root_mean_squared_error: 2.3434 - val_y2_output_root_mean_squared_error: 2.9776
# Epoch 42/500
# 62/62 [==============================] - 0s 4ms/step - loss: 9.8938 - y1_output_loss: 3.5296 - y2_output_loss: 6.3642 - y1_output_root_mean_squared_error: 1.8787 - y2_output_root_mean_squared_error: 2.5227 - val_loss: 9.6865 - val_y1_output_loss: 3.5003 - val_y2_output_loss: 6.1862 - val_y1_output_root_mean_squared_error: 1.8709 - val_y2_output_root_mean_squared_error: 2.4872
# Epoch 43/500
# 62/62 [==============================] - 0s 4ms/step - loss: 9.6328 - y1_output_loss: 3.3216 - y2_output_loss: 6.3112 - y1_output_root_mean_squared_error: 1.8225 - y2_output_root_mean_squared_error: 2.5122 - val_loss: 9.4799 - val_y1_output_loss: 3.7602 - val_y2_output_loss: 5.7198 - val_y1_output_root_mean_squared_error: 1.9391 - val_y2_output_root_mean_squared_error: 2.3916
# Epoch 44/500
# 62/62 [==============================] - 0s 4ms/step - loss: 8.7017 - y1_output_loss: 2.9900 - y2_output_loss: 5.7117 - y1_output_root_mean_squared_error: 1.7292 - y2_output_root_mean_squared_error: 2.3899 - val_loss: 9.1257 - val_y1_output_loss: 3.6275 - val_y2_output_loss: 5.4982 - val_y1_output_root_mean_squared_error: 1.9046 - val_y2_output_root_mean_squared_error: 2.3448
# Epoch 45/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.5943 - y1_output_loss: 2.7109 - y2_output_loss: 4.8834 - y1_output_root_mean_squared_error: 1.6465 - y2_output_root_mean_squared_error: 2.2098 - val_loss: 15.2803 - val_y1_output_loss: 5.4693 - val_y2_output_loss: 9.8110 - val_y1_output_root_mean_squared_error: 2.3387 - val_y2_output_root_mean_squared_error: 3.1322
# Epoch 46/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.2710 - y1_output_loss: 2.5317 - y2_output_loss: 4.7393 - y1_output_root_mean_squared_error: 1.5911 - y2_output_root_mean_squared_error: 2.1770 - val_loss: 8.3688 - val_y1_output_loss: 3.2494 - val_y2_output_loss: 5.1194 - val_y1_output_root_mean_squared_error: 1.8026 - val_y2_output_root_mean_squared_error: 2.2626
# Epoch 47/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.6944 - y1_output_loss: 2.6977 - y2_output_loss: 4.9967 - y1_output_root_mean_squared_error: 1.6425 - y2_output_root_mean_squared_error: 2.2353 - val_loss: 96.0306 - val_y1_output_loss: 31.2861 - val_y2_output_loss: 64.7445 - val_y1_output_root_mean_squared_error: 5.5934 - val_y2_output_root_mean_squared_error: 8.0464
# Epoch 48/500
# 62/62 [==============================] - 0s 4ms/step - loss: 13.8343 - y1_output_loss: 4.6891 - y2_output_loss: 9.1452 - y1_output_root_mean_squared_error: 2.1654 - y2_output_root_mean_squared_error: 3.0241 - val_loss: 9.1976 - val_y1_output_loss: 3.3740 - val_y2_output_loss: 5.8236 - val_y1_output_root_mean_squared_error: 1.8368 - val_y2_output_root_mean_squared_error: 2.4132
# Epoch 49/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.7893 - y1_output_loss: 2.4385 - y2_output_loss: 4.3508 - y1_output_root_mean_squared_error: 1.5616 - y2_output_root_mean_squared_error: 2.0859 - val_loss: 8.9439 - val_y1_output_loss: 3.4901 - val_y2_output_loss: 5.4537 - val_y1_output_root_mean_squared_error: 1.8682 - val_y2_output_root_mean_squared_error: 2.3353
# Epoch 50/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.5921 - y1_output_loss: 2.8426 - y2_output_loss: 5.7495 - y1_output_root_mean_squared_error: 1.6860 - y2_output_root_mean_squared_error: 2.3978 - val_loss: 7.8586 - val_y1_output_loss: 2.5745 - val_y2_output_loss: 5.2841 - val_y1_output_root_mean_squared_error: 1.6045 - val_y2_output_root_mean_squared_error: 2.2987
# Epoch 51/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.6500 - y1_output_loss: 2.4404 - y2_output_loss: 4.2096 - y1_output_root_mean_squared_error: 1.5622 - y2_output_root_mean_squared_error: 2.0517 - val_loss: 10.0146 - val_y1_output_loss: 3.2549 - val_y2_output_loss: 6.7597 - val_y1_output_root_mean_squared_error: 1.8041 - val_y2_output_root_mean_squared_error: 2.5999
# Epoch 52/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.0059 - y1_output_loss: 2.2174 - y2_output_loss: 4.7885 - y1_output_root_mean_squared_error: 1.4891 - y2_output_root_mean_squared_error: 2.1883 - val_loss: 8.3226 - val_y1_output_loss: 2.9754 - val_y2_output_loss: 5.3473 - val_y1_output_root_mean_squared_error: 1.7249 - val_y2_output_root_mean_squared_error: 2.3124
# Epoch 53/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.6303 - y1_output_loss: 1.9600 - y2_output_loss: 3.6702 - y1_output_root_mean_squared_error: 1.4000 - y2_output_root_mean_squared_error: 1.9158 - val_loss: 9.5038 - val_y1_output_loss: 4.2142 - val_y2_output_loss: 5.2897 - val_y1_output_root_mean_squared_error: 2.0528 - val_y2_output_root_mean_squared_error: 2.2999
# Epoch 54/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.2695 - y1_output_loss: 2.2010 - y2_output_loss: 4.0686 - y1_output_root_mean_squared_error: 1.4836 - y2_output_root_mean_squared_error: 2.0171 - val_loss: 7.0028 - val_y1_output_loss: 2.6757 - val_y2_output_loss: 4.3271 - val_y1_output_root_mean_squared_error: 1.6357 - val_y2_output_root_mean_squared_error: 2.0802
# Epoch 55/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.4814 - y1_output_loss: 2.0792 - y2_output_loss: 4.4022 - y1_output_root_mean_squared_error: 1.4419 - y2_output_root_mean_squared_error: 2.0981 - val_loss: 16.1256 - val_y1_output_loss: 5.5957 - val_y2_output_loss: 10.5299 - val_y1_output_root_mean_squared_error: 2.3655 - val_y2_output_root_mean_squared_error: 3.2450
# Epoch 56/500
# 62/62 [==============================] - 0s 4ms/step - loss: 15.3636 - y1_output_loss: 4.8808 - y2_output_loss: 10.4828 - y1_output_root_mean_squared_error: 2.2092 - y2_output_root_mean_squared_error: 3.2377 - val_loss: 10.3126 - val_y1_output_loss: 3.6343 - val_y2_output_loss: 6.6783 - val_y1_output_root_mean_squared_error: 1.9064 - val_y2_output_root_mean_squared_error: 2.5842
# Epoch 57/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.3050 - y1_output_loss: 1.7380 - y2_output_loss: 3.5670 - y1_output_root_mean_squared_error: 1.3183 - y2_output_root_mean_squared_error: 1.8886 - val_loss: 6.4013 - val_y1_output_loss: 2.0182 - val_y2_output_loss: 4.3831 - val_y1_output_root_mean_squared_error: 1.4206 - val_y2_output_root_mean_squared_error: 2.0936
# Epoch 58/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.9538 - y1_output_loss: 2.3924 - y2_output_loss: 5.5614 - y1_output_root_mean_squared_error: 1.5467 - y2_output_root_mean_squared_error: 2.3583 - val_loss: 6.6372 - val_y1_output_loss: 2.3638 - val_y2_output_loss: 4.2734 - val_y1_output_root_mean_squared_error: 1.5375 - val_y2_output_root_mean_squared_error: 2.0672
# Epoch 59/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.7864 - y1_output_loss: 2.1930 - y2_output_loss: 4.5933 - y1_output_root_mean_squared_error: 1.4809 - y2_output_root_mean_squared_error: 2.1432 - val_loss: 6.1416 - val_y1_output_loss: 2.0073 - val_y2_output_loss: 4.1343 - val_y1_output_root_mean_squared_error: 1.4168 - val_y2_output_root_mean_squared_error: 2.0333
# Epoch 60/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.4021 - y1_output_loss: 1.6358 - y2_output_loss: 3.7663 - y1_output_root_mean_squared_error: 1.2790 - y2_output_root_mean_squared_error: 1.9407 - val_loss: 5.9356 - val_y1_output_loss: 2.0586 - val_y2_output_loss: 3.8771 - val_y1_output_root_mean_squared_error: 1.4348 - val_y2_output_root_mean_squared_error: 1.9690
# Epoch 61/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.8184 - y1_output_loss: 1.8889 - y2_output_loss: 3.9295 - y1_output_root_mean_squared_error: 1.3744 - y2_output_root_mean_squared_error: 1.9823 - val_loss: 7.0372 - val_y1_output_loss: 1.9410 - val_y2_output_loss: 5.0962 - val_y1_output_root_mean_squared_error: 1.3932 - val_y2_output_root_mean_squared_error: 2.2575
# Epoch 62/500
# 62/62 [==============================] - 0s 4ms/step - loss: 8.0660 - y1_output_loss: 2.5051 - y2_output_loss: 5.5608 - y1_output_root_mean_squared_error: 1.5828 - y2_output_root_mean_squared_error: 2.3581 - val_loss: 16.8752 - val_y1_output_loss: 3.0996 - val_y2_output_loss: 13.7756 - val_y1_output_root_mean_squared_error: 1.7606 - val_y2_output_root_mean_squared_error: 3.7116
# Epoch 63/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.7891 - y1_output_loss: 1.7990 - y2_output_loss: 3.9901 - y1_output_root_mean_squared_error: 1.3413 - y2_output_root_mean_squared_error: 1.9975 - val_loss: 5.8434 - val_y1_output_loss: 1.8943 - val_y2_output_loss: 3.9491 - val_y1_output_root_mean_squared_error: 1.3763 - val_y2_output_root_mean_squared_error: 1.9872
# Epoch 64/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.1292 - y1_output_loss: 1.5051 - y2_output_loss: 3.6241 - y1_output_root_mean_squared_error: 1.2268 - y2_output_root_mean_squared_error: 1.9037 - val_loss: 6.8205 - val_y1_output_loss: 2.5870 - val_y2_output_loss: 4.2335 - val_y1_output_root_mean_squared_error: 1.6084 - val_y2_output_root_mean_squared_error: 2.0575
# Epoch 65/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5787 - y1_output_loss: 1.8286 - y2_output_loss: 3.7500 - y1_output_root_mean_squared_error: 1.3523 - y2_output_root_mean_squared_error: 1.9365 - val_loss: 5.8454 - val_y1_output_loss: 1.7516 - val_y2_output_loss: 4.0939 - val_y1_output_root_mean_squared_error: 1.3235 - val_y2_output_root_mean_squared_error: 2.0233
# Epoch 66/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5586 - y1_output_loss: 1.7544 - y2_output_loss: 3.8043 - y1_output_root_mean_squared_error: 1.3245 - y2_output_root_mean_squared_error: 1.9504 - val_loss: 5.4265 - val_y1_output_loss: 1.7150 - val_y2_output_loss: 3.7115 - val_y1_output_root_mean_squared_error: 1.3096 - val_y2_output_root_mean_squared_error: 1.9265
# Epoch 67/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.7327 - y1_output_loss: 1.3195 - y2_output_loss: 3.4131 - y1_output_root_mean_squared_error: 1.1487 - y2_output_root_mean_squared_error: 1.8475 - val_loss: 8.6854 - val_y1_output_loss: 2.5445 - val_y2_output_loss: 6.1409 - val_y1_output_root_mean_squared_error: 1.5952 - val_y2_output_root_mean_squared_error: 2.4781
# Epoch 68/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.1630 - y1_output_loss: 1.4685 - y2_output_loss: 3.6945 - y1_output_root_mean_squared_error: 1.2118 - y2_output_root_mean_squared_error: 1.9221 - val_loss: 16.1557 - val_y1_output_loss: 3.0590 - val_y2_output_loss: 13.0967 - val_y1_output_root_mean_squared_error: 1.7490 - val_y2_output_root_mean_squared_error: 3.6189
# Epoch 69/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5904 - y1_output_loss: 1.5613 - y2_output_loss: 4.0292 - y1_output_root_mean_squared_error: 1.2495 - y2_output_root_mean_squared_error: 2.0073 - val_loss: 5.7412 - val_y1_output_loss: 1.7147 - val_y2_output_loss: 4.0265 - val_y1_output_root_mean_squared_error: 1.3095 - val_y2_output_root_mean_squared_error: 2.0066
# Epoch 70/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.5674 - y1_output_loss: 1.3994 - y2_output_loss: 3.1680 - y1_output_root_mean_squared_error: 1.1830 - y2_output_root_mean_squared_error: 1.7799 - val_loss: 5.2765 - val_y1_output_loss: 1.6690 - val_y2_output_loss: 3.6074 - val_y1_output_root_mean_squared_error: 1.2919 - val_y2_output_root_mean_squared_error: 1.8993
# Epoch 71/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.1943 - y1_output_loss: 1.3289 - y2_output_loss: 2.8655 - y1_output_root_mean_squared_error: 1.1528 - y2_output_root_mean_squared_error: 1.6928 - val_loss: 9.3945 - val_y1_output_loss: 2.9174 - val_y2_output_loss: 6.4772 - val_y1_output_root_mean_squared_error: 1.7080 - val_y2_output_root_mean_squared_error: 2.5450
# Epoch 72/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.3350 - y1_output_loss: 1.3557 - y2_output_loss: 2.9793 - y1_output_root_mean_squared_error: 1.1643 - y2_output_root_mean_squared_error: 1.7261 - val_loss: 7.0224 - val_y1_output_loss: 1.8363 - val_y2_output_loss: 5.1861 - val_y1_output_root_mean_squared_error: 1.3551 - val_y2_output_root_mean_squared_error: 2.2773
# Epoch 73/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.2153 - y1_output_loss: 1.3694 - y2_output_loss: 2.8459 - y1_output_root_mean_squared_error: 1.1702 - y2_output_root_mean_squared_error: 1.6870 - val_loss: 4.2382 - val_y1_output_loss: 1.3291 - val_y2_output_loss: 2.9091 - val_y1_output_root_mean_squared_error: 1.1529 - val_y2_output_root_mean_squared_error: 1.7056
# Epoch 74/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.8787 - y1_output_loss: 1.1974 - y2_output_loss: 2.6813 - y1_output_root_mean_squared_error: 1.0943 - y2_output_root_mean_squared_error: 1.6375 - val_loss: 7.8943 - val_y1_output_loss: 1.3201 - val_y2_output_loss: 6.5742 - val_y1_output_root_mean_squared_error: 1.1489 - val_y2_output_root_mean_squared_error: 2.5640
# Epoch 75/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.7816 - y1_output_loss: 1.3760 - y2_output_loss: 4.4056 - y1_output_root_mean_squared_error: 1.1731 - y2_output_root_mean_squared_error: 2.0989 - val_loss: 6.7993 - val_y1_output_loss: 2.3664 - val_y2_output_loss: 4.4329 - val_y1_output_root_mean_squared_error: 1.5383 - val_y2_output_root_mean_squared_error: 2.1054
# Epoch 76/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.9469 - y1_output_loss: 1.4498 - y2_output_loss: 3.4970 - y1_output_root_mean_squared_error: 1.2041 - y2_output_root_mean_squared_error: 1.8700 - val_loss: 4.7678 - val_y1_output_loss: 1.5644 - val_y2_output_loss: 3.2034 - val_y1_output_root_mean_squared_error: 1.2508 - val_y2_output_root_mean_squared_error: 1.7898
# Epoch 77/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.0295 - y1_output_loss: 1.0874 - y2_output_loss: 2.9421 - y1_output_root_mean_squared_error: 1.0428 - y2_output_root_mean_squared_error: 1.7152 - val_loss: 4.0975 - val_y1_output_loss: 1.1845 - val_y2_output_loss: 2.9131 - val_y1_output_root_mean_squared_error: 1.0883 - val_y2_output_root_mean_squared_error: 1.7068
# Epoch 78/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.6801 - y1_output_loss: 1.0118 - y2_output_loss: 2.6683 - y1_output_root_mean_squared_error: 1.0059 - y2_output_root_mean_squared_error: 1.6335 - val_loss: 4.4801 - val_y1_output_loss: 1.4110 - val_y2_output_loss: 3.0691 - val_y1_output_root_mean_squared_error: 1.1879 - val_y2_output_root_mean_squared_error: 1.7519
# Epoch 79/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.1989 - y1_output_loss: 0.9574 - y2_output_loss: 2.2415 - y1_output_root_mean_squared_error: 0.9785 - y2_output_root_mean_squared_error: 1.4972 - val_loss: 7.5291 - val_y1_output_loss: 2.4192 - val_y2_output_loss: 5.1099 - val_y1_output_root_mean_squared_error: 1.5554 - val_y2_output_root_mean_squared_error: 2.2605
# Epoch 80/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.2310 - y1_output_loss: 1.0271 - y2_output_loss: 2.2039 - y1_output_root_mean_squared_error: 1.0135 - y2_output_root_mean_squared_error: 1.4846 - val_loss: 3.9401 - val_y1_output_loss: 1.0325 - val_y2_output_loss: 2.9076 - val_y1_output_root_mean_squared_error: 1.0161 - val_y2_output_root_mean_squared_error: 1.7052
# Epoch 81/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.0325 - y1_output_loss: 1.1489 - y2_output_loss: 2.8836 - y1_output_root_mean_squared_error: 1.0719 - y2_output_root_mean_squared_error: 1.6981 - val_loss: 3.7826 - val_y1_output_loss: 0.9834 - val_y2_output_loss: 2.7992 - val_y1_output_root_mean_squared_error: 0.9917 - val_y2_output_root_mean_squared_error: 1.6731
# Epoch 82/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.2312 - y1_output_loss: 0.8830 - y2_output_loss: 2.3482 - y1_output_root_mean_squared_error: 0.9397 - y2_output_root_mean_squared_error: 1.5324 - val_loss: 28.1800 - val_y1_output_loss: 9.8132 - val_y2_output_loss: 18.3669 - val_y1_output_root_mean_squared_error: 3.1326 - val_y2_output_root_mean_squared_error: 4.2857
# Epoch 83/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.6612 - y1_output_loss: 0.9927 - y2_output_loss: 2.6685 - y1_output_root_mean_squared_error: 0.9963 - y2_output_root_mean_squared_error: 1.6336 - val_loss: 4.9591 - val_y1_output_loss: 1.6792 - val_y2_output_loss: 3.2799 - val_y1_output_root_mean_squared_error: 1.2959 - val_y2_output_root_mean_squared_error: 1.8110
# Epoch 84/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.5996 - y1_output_loss: 1.2013 - y2_output_loss: 3.3983 - y1_output_root_mean_squared_error: 1.0960 - y2_output_root_mean_squared_error: 1.8434 - val_loss: 4.9199 - val_y1_output_loss: 0.9516 - val_y2_output_loss: 3.9683 - val_y1_output_root_mean_squared_error: 0.9755 - val_y2_output_root_mean_squared_error: 1.9920
# Epoch 85/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.6971 - y1_output_loss: 1.1313 - y2_output_loss: 3.5658 - y1_output_root_mean_squared_error: 1.0636 - y2_output_root_mean_squared_error: 1.8883 - val_loss: 3.9779 - val_y1_output_loss: 0.9482 - val_y2_output_loss: 3.0298 - val_y1_output_root_mean_squared_error: 0.9737 - val_y2_output_root_mean_squared_error: 1.7406
# Epoch 86/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.6256 - y1_output_loss: 1.2954 - y2_output_loss: 4.3303 - y1_output_root_mean_squared_error: 1.1381 - y2_output_root_mean_squared_error: 2.0809 - val_loss: 65.3872 - val_y1_output_loss: 18.9685 - val_y2_output_loss: 46.4187 - val_y1_output_root_mean_squared_error: 4.3553 - val_y2_output_root_mean_squared_error: 6.8131
# Epoch 87/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.9441 - y1_output_loss: 1.5637 - y2_output_loss: 3.3804 - y1_output_root_mean_squared_error: 1.2505 - y2_output_root_mean_squared_error: 1.8386 - val_loss: 3.4630 - val_y1_output_loss: 0.9360 - val_y2_output_loss: 2.5269 - val_y1_output_root_mean_squared_error: 0.9675 - val_y2_output_root_mean_squared_error: 1.5896
# Epoch 88/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.8940 - y1_output_loss: 0.9773 - y2_output_loss: 2.9167 - y1_output_root_mean_squared_error: 0.9886 - y2_output_root_mean_squared_error: 1.7078 - val_loss: 4.0114 - val_y1_output_loss: 0.8714 - val_y2_output_loss: 3.1400 - val_y1_output_root_mean_squared_error: 0.9335 - val_y2_output_root_mean_squared_error: 1.7720
# Epoch 89/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.6853 - y1_output_loss: 0.9155 - y2_output_loss: 2.7698 - y1_output_root_mean_squared_error: 0.9568 - y2_output_root_mean_squared_error: 1.6643 - val_loss: 3.5031 - val_y1_output_loss: 0.8758 - val_y2_output_loss: 2.6273 - val_y1_output_root_mean_squared_error: 0.9359 - val_y2_output_root_mean_squared_error: 1.6209
# Epoch 90/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.7569 - y1_output_loss: 0.7786 - y2_output_loss: 1.9783 - y1_output_root_mean_squared_error: 0.8824 - y2_output_root_mean_squared_error: 1.4065 - val_loss: 5.5703 - val_y1_output_loss: 0.9084 - val_y2_output_loss: 4.6619 - val_y1_output_root_mean_squared_error: 0.9531 - val_y2_output_root_mean_squared_error: 2.1592
# Epoch 91/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.9823 - y1_output_loss: 0.7823 - y2_output_loss: 2.2000 - y1_output_root_mean_squared_error: 0.8845 - y2_output_root_mean_squared_error: 1.4832 - val_loss: 4.3394 - val_y1_output_loss: 0.7359 - val_y2_output_loss: 3.6035 - val_y1_output_root_mean_squared_error: 0.8578 - val_y2_output_root_mean_squared_error: 1.8983
# Epoch 92/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.1706 - y1_output_loss: 0.7191 - y2_output_loss: 2.4515 - y1_output_root_mean_squared_error: 0.8480 - y2_output_root_mean_squared_error: 1.5657 - val_loss: 4.1835 - val_y1_output_loss: 0.7863 - val_y2_output_loss: 3.3972 - val_y1_output_root_mean_squared_error: 0.8868 - val_y2_output_root_mean_squared_error: 1.8431
# Epoch 93/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.9592 - y1_output_loss: 0.7396 - y2_output_loss: 2.2197 - y1_output_root_mean_squared_error: 0.8600 - y2_output_root_mean_squared_error: 1.4899 - val_loss: 3.1710 - val_y1_output_loss: 0.7018 - val_y2_output_loss: 2.4692 - val_y1_output_root_mean_squared_error: 0.8377 - val_y2_output_root_mean_squared_error: 1.5714
# Epoch 94/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.6321 - y1_output_loss: 0.6069 - y2_output_loss: 2.0252 - y1_output_root_mean_squared_error: 0.7791 - y2_output_root_mean_squared_error: 1.4231 - val_loss: 3.6006 - val_y1_output_loss: 0.9263 - val_y2_output_loss: 2.6742 - val_y1_output_root_mean_squared_error: 0.9625 - val_y2_output_root_mean_squared_error: 1.6353
# Epoch 95/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.5421 - y1_output_loss: 0.5897 - y2_output_loss: 1.9523 - y1_output_root_mean_squared_error: 0.7680 - y2_output_root_mean_squared_error: 1.3973 - val_loss: 4.7003 - val_y1_output_loss: 0.7392 - val_y2_output_loss: 3.9611 - val_y1_output_root_mean_squared_error: 0.8598 - val_y2_output_root_mean_squared_error: 1.9903
# Epoch 96/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.6611 - y1_output_loss: 0.6298 - y2_output_loss: 2.0313 - y1_output_root_mean_squared_error: 0.7936 - y2_output_root_mean_squared_error: 1.4253 - val_loss: 3.2389 - val_y1_output_loss: 0.8533 - val_y2_output_loss: 2.3856 - val_y1_output_root_mean_squared_error: 0.9238 - val_y2_output_root_mean_squared_error: 1.5445
# Epoch 97/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.7438 - y1_output_loss: 0.7054 - y2_output_loss: 2.0384 - y1_output_root_mean_squared_error: 0.8399 - y2_output_root_mean_squared_error: 1.4277 - val_loss: 4.5818 - val_y1_output_loss: 0.9960 - val_y2_output_loss: 3.5857 - val_y1_output_root_mean_squared_error: 0.9980 - val_y2_output_root_mean_squared_error: 1.8936
# Epoch 98/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.7694 - y1_output_loss: 0.6802 - y2_output_loss: 2.0892 - y1_output_root_mean_squared_error: 0.8247 - y2_output_root_mean_squared_error: 1.4454 - val_loss: 3.9233 - val_y1_output_loss: 1.3353 - val_y2_output_loss: 2.5880 - val_y1_output_root_mean_squared_error: 1.1556 - val_y2_output_root_mean_squared_error: 1.6087
# Epoch 99/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.6642 - y1_output_loss: 0.9205 - y2_output_loss: 2.7437 - y1_output_root_mean_squared_error: 0.9594 - y2_output_root_mean_squared_error: 1.6564 - val_loss: 3.4313 - val_y1_output_loss: 0.8105 - val_y2_output_loss: 2.6208 - val_y1_output_root_mean_squared_error: 0.9003 - val_y2_output_root_mean_squared_error: 1.6189
# Epoch 100/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.8258 - y1_output_loss: 0.8095 - y2_output_loss: 2.0163 - y1_output_root_mean_squared_error: 0.8997 - y2_output_root_mean_squared_error: 1.4200 - val_loss: 3.3394 - val_y1_output_loss: 0.8515 - val_y2_output_loss: 2.4879 - val_y1_output_root_mean_squared_error: 0.9228 - val_y2_output_root_mean_squared_error: 1.5773
# Epoch 101/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.5582 - y1_output_loss: 0.6161 - y2_output_loss: 1.9421 - y1_output_root_mean_squared_error: 0.7849 - y2_output_root_mean_squared_error: 1.3936 - val_loss: 13.1075 - val_y1_output_loss: 4.3926 - val_y2_output_loss: 8.7149 - val_y1_output_root_mean_squared_error: 2.0958 - val_y2_output_root_mean_squared_error: 2.9521
# Epoch 102/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.5788 - y1_output_loss: 0.6612 - y2_output_loss: 1.9176 - y1_output_root_mean_squared_error: 0.8131 - y2_output_root_mean_squared_error: 1.3848 - val_loss: 3.2616 - val_y1_output_loss: 0.8476 - val_y2_output_loss: 2.4141 - val_y1_output_root_mean_squared_error: 0.9206 - val_y2_output_root_mean_squared_error: 1.5537
# Epoch 103/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.2001 - y1_output_loss: 1.3797 - y2_output_loss: 3.8204 - y1_output_root_mean_squared_error: 1.1746 - y2_output_root_mean_squared_error: 1.9546 - val_loss: 3.2382 - val_y1_output_loss: 0.7801 - val_y2_output_loss: 2.4581 - val_y1_output_root_mean_squared_error: 0.8832 - val_y2_output_root_mean_squared_error: 1.5678
# Epoch 104/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.0190 - y1_output_loss: 0.7704 - y2_output_loss: 2.2486 - y1_output_root_mean_squared_error: 0.8777 - y2_output_root_mean_squared_error: 1.4995 - val_loss: 3.5934 - val_y1_output_loss: 0.8623 - val_y2_output_loss: 2.7311 - val_y1_output_root_mean_squared_error: 0.9286 - val_y2_output_root_mean_squared_error: 1.6526
# Epoch 105/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.6250 - y1_output_loss: 0.5996 - y2_output_loss: 2.0254 - y1_output_root_mean_squared_error: 0.7744 - y2_output_root_mean_squared_error: 1.4231 - val_loss: 7.8828 - val_y1_output_loss: 1.3759 - val_y2_output_loss: 6.5069 - val_y1_output_root_mean_squared_error: 1.1730 - val_y2_output_root_mean_squared_error: 2.5509
# Epoch 106/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.2332 - y1_output_loss: 0.7358 - y2_output_loss: 2.4974 - y1_output_root_mean_squared_error: 0.8578 - y2_output_root_mean_squared_error: 1.5803 - val_loss: 3.9120 - val_y1_output_loss: 1.0047 - val_y2_output_loss: 2.9073 - val_y1_output_root_mean_squared_error: 1.0023 - val_y2_output_root_mean_squared_error: 1.7051
# Epoch 107/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.3452 - y1_output_loss: 0.6074 - y2_output_loss: 1.7378 - y1_output_root_mean_squared_error: 0.7793 - y2_output_root_mean_squared_error: 1.3183 - val_loss: 4.3141 - val_y1_output_loss: 0.6477 - val_y2_output_loss: 3.6664 - val_y1_output_root_mean_squared_error: 0.8048 - val_y2_output_root_mean_squared_error: 1.9148
# Epoch 108/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.2302 - y1_output_loss: 0.8128 - y2_output_loss: 2.4173 - y1_output_root_mean_squared_error: 0.9016 - y2_output_root_mean_squared_error: 1.5548 - val_loss: 3.3990 - val_y1_output_loss: 0.8311 - val_y2_output_loss: 2.5679 - val_y1_output_root_mean_squared_error: 0.9117 - val_y2_output_root_mean_squared_error: 1.6025
# Epoch 109/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.4716 - y1_output_loss: 0.6182 - y2_output_loss: 1.8534 - y1_output_root_mean_squared_error: 0.7863 - y2_output_root_mean_squared_error: 1.3614 - val_loss: 2.7309 - val_y1_output_loss: 0.6479 - val_y2_output_loss: 2.0830 - val_y1_output_root_mean_squared_error: 0.8049 - val_y2_output_root_mean_squared_error: 1.4433
# Epoch 110/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.3221 - y1_output_loss: 0.5277 - y2_output_loss: 1.7943 - y1_output_root_mean_squared_error: 0.7265 - y2_output_root_mean_squared_error: 1.3395 - val_loss: 4.0081 - val_y1_output_loss: 1.1091 - val_y2_output_loss: 2.8990 - val_y1_output_root_mean_squared_error: 1.0531 - val_y2_output_root_mean_squared_error: 1.7027
# Epoch 111/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.1646 - y1_output_loss: 0.5111 - y2_output_loss: 1.6535 - y1_output_root_mean_squared_error: 0.7149 - y2_output_root_mean_squared_error: 1.2859 - val_loss: 4.5491 - val_y1_output_loss: 1.5733 - val_y2_output_loss: 2.9757 - val_y1_output_root_mean_squared_error: 1.2543 - val_y2_output_root_mean_squared_error: 1.7250
# Epoch 112/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.5139 - y1_output_loss: 0.6416 - y2_output_loss: 1.8723 - y1_output_root_mean_squared_error: 0.8010 - y2_output_root_mean_squared_error: 1.3683 - val_loss: 3.4042 - val_y1_output_loss: 0.7476 - val_y2_output_loss: 2.6566 - val_y1_output_root_mean_squared_error: 0.8647 - val_y2_output_root_mean_squared_error: 1.6299
# Epoch 113/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.9435 - y1_output_loss: 0.6711 - y2_output_loss: 2.2725 - y1_output_root_mean_squared_error: 0.8192 - y2_output_root_mean_squared_error: 1.5075 - val_loss: 7.0178 - val_y1_output_loss: 2.0168 - val_y2_output_loss: 5.0009 - val_y1_output_root_mean_squared_error: 1.4202 - val_y2_output_root_mean_squared_error: 2.2363
# Epoch 114/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.2223 - y1_output_loss: 0.7744 - y2_output_loss: 2.4478 - y1_output_root_mean_squared_error: 0.8800 - y2_output_root_mean_squared_error: 1.5646 - val_loss: 3.6575 - val_y1_output_loss: 0.9042 - val_y2_output_loss: 2.7533 - val_y1_output_root_mean_squared_error: 0.9509 - val_y2_output_root_mean_squared_error: 1.6593
# Epoch 115/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.2452 - y1_output_loss: 0.5429 - y2_output_loss: 1.7023 - y1_output_root_mean_squared_error: 0.7368 - y2_output_root_mean_squared_error: 1.3047 - val_loss: 2.9981 - val_y1_output_loss: 0.6563 - val_y2_output_loss: 2.3419 - val_y1_output_root_mean_squared_error: 0.8101 - val_y2_output_root_mean_squared_error: 1.5303
# Epoch 116/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.1191 - y1_output_loss: 0.5476 - y2_output_loss: 1.5716 - y1_output_root_mean_squared_error: 0.7400 - y2_output_root_mean_squared_error: 1.2536 - val_loss: 2.6572 - val_y1_output_loss: 0.5064 - val_y2_output_loss: 2.1509 - val_y1_output_root_mean_squared_error: 0.7116 - val_y2_output_root_mean_squared_error: 1.4666
# Epoch 117/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.2407 - y1_output_loss: 0.5474 - y2_output_loss: 1.6933 - y1_output_root_mean_squared_error: 0.7398 - y2_output_root_mean_squared_error: 1.3013 - val_loss: 3.8145 - val_y1_output_loss: 0.5568 - val_y2_output_loss: 3.2577 - val_y1_output_root_mean_squared_error: 0.7462 - val_y2_output_root_mean_squared_error: 1.8049
# Epoch 118/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.1980 - y1_output_loss: 0.5277 - y2_output_loss: 1.6703 - y1_output_root_mean_squared_error: 0.7265 - y2_output_root_mean_squared_error: 1.2924 - val_loss: 2.9936 - val_y1_output_loss: 0.5969 - val_y2_output_loss: 2.3968 - val_y1_output_root_mean_squared_error: 0.7726 - val_y2_output_root_mean_squared_error: 1.5481
# Epoch 119/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.0562 - y1_output_loss: 0.5088 - y2_output_loss: 1.5474 - y1_output_root_mean_squared_error: 0.7133 - y2_output_root_mean_squared_error: 1.2440 - val_loss: 3.4408 - val_y1_output_loss: 0.9471 - val_y2_output_loss: 2.4937 - val_y1_output_root_mean_squared_error: 0.9732 - val_y2_output_root_mean_squared_error: 1.5791
# Epoch 120/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.2517 - y1_output_loss: 0.9914 - y2_output_loss: 3.2603 - y1_output_root_mean_squared_error: 0.9957 - y2_output_root_mean_squared_error: 1.8056 - val_loss: 3.0708 - val_y1_output_loss: 0.8309 - val_y2_output_loss: 2.2399 - val_y1_output_root_mean_squared_error: 0.9115 - val_y2_output_root_mean_squared_error: 1.4966
# Epoch 121/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.4274 - y1_output_loss: 0.5893 - y2_output_loss: 1.8381 - y1_output_root_mean_squared_error: 0.7677 - y2_output_root_mean_squared_error: 1.3558 - val_loss: 3.1724 - val_y1_output_loss: 0.9193 - val_y2_output_loss: 2.2531 - val_y1_output_root_mean_squared_error: 0.9588 - val_y2_output_root_mean_squared_error: 1.5010
# Epoch 122/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4905 - y1_output_loss: 0.1418 - y2_output_loss: 0.3487 - y1_output_root_mean_squared_error: 0.3766 - y2_output_root_mean_squared_error: 0.5905 - val_loss: 1.8296 - val_y1_output_loss: 0.3156 - val_y2_output_loss: 1.5140 - val_y1_output_root_mean_squared_error: 0.5618 - val_y2_output_root_mean_squared_error: 1.2304
# Epoch 462/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4458 - y1_output_loss: 0.1272 - y2_output_loss: 0.3187 - y1_output_root_mean_squared_error: 0.3566 - y2_output_root_mean_squared_error: 0.5645 - val_loss: 1.4709 - val_y1_output_loss: 0.1882 - val_y2_output_loss: 1.2827 - val_y1_output_root_mean_squared_error: 0.4338 - val_y2_output_root_mean_squared_error: 1.1326
# Epoch 463/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4159 - y1_output_loss: 0.1129 - y2_output_loss: 0.3030 - y1_output_root_mean_squared_error: 0.3360 - y2_output_root_mean_squared_error: 0.5505 - val_loss: 2.5585 - val_y1_output_loss: 0.1986 - val_y2_output_loss: 2.3599 - val_y1_output_root_mean_squared_error: 0.4457 - val_y2_output_root_mean_squared_error: 1.5362
# Epoch 464/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4287 - y1_output_loss: 0.1188 - y2_output_loss: 0.3099 - y1_output_root_mean_squared_error: 0.3447 - y2_output_root_mean_squared_error: 0.5567 - val_loss: 1.3693 - val_y1_output_loss: 0.3096 - val_y2_output_loss: 1.0597 - val_y1_output_root_mean_squared_error: 0.5564 - val_y2_output_root_mean_squared_error: 1.0294
# Epoch 465/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4071 - y1_output_loss: 0.1357 - y2_output_loss: 0.2714 - y1_output_root_mean_squared_error: 0.3684 - y2_output_root_mean_squared_error: 0.5210 - val_loss: 1.1117 - val_y1_output_loss: 0.1961 - val_y2_output_loss: 0.9155 - val_y1_output_root_mean_squared_error: 0.4429 - val_y2_output_root_mean_squared_error: 0.9568
# Epoch 466/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4244 - y1_output_loss: 0.1349 - y2_output_loss: 0.2895 - y1_output_root_mean_squared_error: 0.3673 - y2_output_root_mean_squared_error: 0.5380 - val_loss: 2.2479 - val_y1_output_loss: 0.2640 - val_y2_output_loss: 1.9839 - val_y1_output_root_mean_squared_error: 0.5138 - val_y2_output_root_mean_squared_error: 1.4085
# Epoch 467/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4782 - y1_output_loss: 0.1429 - y2_output_loss: 0.3353 - y1_output_root_mean_squared_error: 0.3781 - y2_output_root_mean_squared_error: 0.5790 - val_loss: 1.1490 - val_y1_output_loss: 0.1736 - val_y2_output_loss: 0.9754 - val_y1_output_root_mean_squared_error: 0.4166 - val_y2_output_root_mean_squared_error: 0.9876
# Epoch 468/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3939 - y1_output_loss: 0.1264 - y2_output_loss: 0.2676 - y1_output_root_mean_squared_error: 0.3555 - y2_output_root_mean_squared_error: 0.5173 - val_loss: 1.0570 - val_y1_output_loss: 0.1411 - val_y2_output_loss: 0.9160 - val_y1_output_root_mean_squared_error: 0.3756 - val_y2_output_root_mean_squared_error: 0.9571
# Epoch 469/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4064 - y1_output_loss: 0.1315 - y2_output_loss: 0.2749 - y1_output_root_mean_squared_error: 0.3627 - y2_output_root_mean_squared_error: 0.5243 - val_loss: 1.0229 - val_y1_output_loss: 0.1842 - val_y2_output_loss: 0.8387 - val_y1_output_root_mean_squared_error: 0.4292 - val_y2_output_root_mean_squared_error: 0.9158
# Epoch 470/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5526 - y1_output_loss: 0.1435 - y2_output_loss: 0.4091 - y1_output_root_mean_squared_error: 0.3788 - y2_output_root_mean_squared_error: 0.6396 - val_loss: 1.3125 - val_y1_output_loss: 0.1907 - val_y2_output_loss: 1.1218 - val_y1_output_root_mean_squared_error: 0.4367 - val_y2_output_root_mean_squared_error: 1.0591
# Epoch 471/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4712 - y1_output_loss: 0.1393 - y2_output_loss: 0.3319 - y1_output_root_mean_squared_error: 0.3732 - y2_output_root_mean_squared_error: 0.5761 - val_loss: 1.2549 - val_y1_output_loss: 0.1545 - val_y2_output_loss: 1.1004 - val_y1_output_root_mean_squared_error: 0.3931 - val_y2_output_root_mean_squared_error: 1.0490
# Epoch 472/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4140 - y1_output_loss: 0.1287 - y2_output_loss: 0.2852 - y1_output_root_mean_squared_error: 0.3588 - y2_output_root_mean_squared_error: 0.5341 - val_loss: 1.1096 - val_y1_output_loss: 0.2058 - val_y2_output_loss: 0.9038 - val_y1_output_root_mean_squared_error: 0.4536 - val_y2_output_root_mean_squared_error: 0.9507
# Epoch 473/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3931 - y1_output_loss: 0.1300 - y2_output_loss: 0.2631 - y1_output_root_mean_squared_error: 0.3606 - y2_output_root_mean_squared_error: 0.5129 - val_loss: 1.6210 - val_y1_output_loss: 0.3199 - val_y2_output_loss: 1.3012 - val_y1_output_root_mean_squared_error: 0.5656 - val_y2_output_root_mean_squared_error: 1.1407
# Epoch 474/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4563 - y1_output_loss: 0.1410 - y2_output_loss: 0.3153 - y1_output_root_mean_squared_error: 0.3754 - y2_output_root_mean_squared_error: 0.5615 - val_loss: 1.2521 - val_y1_output_loss: 0.2486 - val_y2_output_loss: 1.0035 - val_y1_output_root_mean_squared_error: 0.4986 - val_y2_output_root_mean_squared_error: 1.0017
# Epoch 475/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4956 - y1_output_loss: 0.1399 - y2_output_loss: 0.3557 - y1_output_root_mean_squared_error: 0.3740 - y2_output_root_mean_squared_error: 0.5964 - val_loss: 1.0297 - val_y1_output_loss: 0.1705 - val_y2_output_loss: 0.8592 - val_y1_output_root_mean_squared_error: 0.4129 - val_y2_output_root_mean_squared_error: 0.9269
# Epoch 476/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3528 - y1_output_loss: 0.1171 - y2_output_loss: 0.2358 - y1_output_root_mean_squared_error: 0.3421 - y2_output_root_mean_squared_error: 0.4855 - val_loss: 1.1459 - val_y1_output_loss: 0.1886 - val_y2_output_loss: 0.9573 - val_y1_output_root_mean_squared_error: 0.4343 - val_y2_output_root_mean_squared_error: 0.9784
# Epoch 477/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4922 - y1_output_loss: 0.1442 - y2_output_loss: 0.3480 - y1_output_root_mean_squared_error: 0.3798 - y2_output_root_mean_squared_error: 0.5899 - val_loss: 1.2257 - val_y1_output_loss: 0.1815 - val_y2_output_loss: 1.0442 - val_y1_output_root_mean_squared_error: 0.4260 - val_y2_output_root_mean_squared_error: 1.0219
# Epoch 478/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4291 - y1_output_loss: 0.1351 - y2_output_loss: 0.2940 - y1_output_root_mean_squared_error: 0.3676 - y2_output_root_mean_squared_error: 0.5422 - val_loss: 1.0361 - val_y1_output_loss: 0.1625 - val_y2_output_loss: 0.8736 - val_y1_output_root_mean_squared_error: 0.4031 - val_y2_output_root_mean_squared_error: 0.9347
# Epoch 479/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4019 - y1_output_loss: 0.1178 - y2_output_loss: 0.2841 - y1_output_root_mean_squared_error: 0.3432 - y2_output_root_mean_squared_error: 0.5330 - val_loss: 1.3930 - val_y1_output_loss: 0.3234 - val_y2_output_loss: 1.0695 - val_y1_output_root_mean_squared_error: 0.5687 - val_y2_output_root_mean_squared_error: 1.0342
# Epoch 480/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5690 - y1_output_loss: 0.1610 - y2_output_loss: 0.4080 - y1_output_root_mean_squared_error: 0.4013 - y2_output_root_mean_squared_error: 0.6388 - val_loss: 3.1705 - val_y1_output_loss: 0.3265 - val_y2_output_loss: 2.8440 - val_y1_output_root_mean_squared_error: 0.5714 - val_y2_output_root_mean_squared_error: 1.6864
# Epoch 481/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6002 - y1_output_loss: 0.1886 - y2_output_loss: 0.4116 - y1_output_root_mean_squared_error: 0.4343 - y2_output_root_mean_squared_error: 0.6416 - val_loss: 1.2747 - val_y1_output_loss: 0.2211 - val_y2_output_loss: 1.0536 - val_y1_output_root_mean_squared_error: 0.4702 - val_y2_output_root_mean_squared_error: 1.0264
# Epoch 482/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4401 - y1_output_loss: 0.1343 - y2_output_loss: 0.3058 - y1_output_root_mean_squared_error: 0.3665 - y2_output_root_mean_squared_error: 0.5530 - val_loss: 1.3063 - val_y1_output_loss: 0.1916 - val_y2_output_loss: 1.1147 - val_y1_output_root_mean_squared_error: 0.4378 - val_y2_output_root_mean_squared_error: 1.0558
# Epoch 483/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6897 - y1_output_loss: 0.1746 - y2_output_loss: 0.5151 - y1_output_root_mean_squared_error: 0.4178 - y2_output_root_mean_squared_error: 0.7177 - val_loss: 1.0259 - val_y1_output_loss: 0.1415 - val_y2_output_loss: 0.8844 - val_y1_output_root_mean_squared_error: 0.3761 - val_y2_output_root_mean_squared_error: 0.9404
# Epoch 484/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4648 - y1_output_loss: 0.1318 - y2_output_loss: 0.3330 - y1_output_root_mean_squared_error: 0.3630 - y2_output_root_mean_squared_error: 0.5771 - val_loss: 1.1782 - val_y1_output_loss: 0.2012 - val_y2_output_loss: 0.9770 - val_y1_output_root_mean_squared_error: 0.4485 - val_y2_output_root_mean_squared_error: 0.9884
# Epoch 485/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4737 - y1_output_loss: 0.1367 - y2_output_loss: 0.3370 - y1_output_root_mean_squared_error: 0.3697 - y2_output_root_mean_squared_error: 0.5805 - val_loss: 1.3614 - val_y1_output_loss: 0.2277 - val_y2_output_loss: 1.1337 - val_y1_output_root_mean_squared_error: 0.4772 - val_y2_output_root_mean_squared_error: 1.0647
# Epoch 486/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3771 - y1_output_loss: 0.1199 - y2_output_loss: 0.2572 - y1_output_root_mean_squared_error: 0.3462 - y2_output_root_mean_squared_error: 0.5072 - val_loss: 1.1598 - val_y1_output_loss: 0.1885 - val_y2_output_loss: 0.9714 - val_y1_output_root_mean_squared_error: 0.4341 - val_y2_output_root_mean_squared_error: 0.9856
# Epoch 487/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4859 - y1_output_loss: 0.1493 - y2_output_loss: 0.3366 - y1_output_root_mean_squared_error: 0.3864 - y2_output_root_mean_squared_error: 0.5802 - val_loss: 1.0404 - val_y1_output_loss: 0.1635 - val_y2_output_loss: 0.8769 - val_y1_output_root_mean_squared_error: 0.4043 - val_y2_output_root_mean_squared_error: 0.9364
# Epoch 488/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4612 - y1_output_loss: 0.1377 - y2_output_loss: 0.3235 - y1_output_root_mean_squared_error: 0.3710 - y2_output_root_mean_squared_error: 0.5688 - val_loss: 0.9758 - val_y1_output_loss: 0.1590 - val_y2_output_loss: 0.8169 - val_y1_output_root_mean_squared_error: 0.3987 - val_y2_output_root_mean_squared_error: 0.9038
# Epoch 489/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5352 - y1_output_loss: 0.1514 - y2_output_loss: 0.3838 - y1_output_root_mean_squared_error: 0.3891 - y2_output_root_mean_squared_error: 0.6195 - val_loss: 1.4729 - val_y1_output_loss: 0.2739 - val_y2_output_loss: 1.1990 - val_y1_output_root_mean_squared_error: 0.5233 - val_y2_output_root_mean_squared_error: 1.0950
# Epoch 490/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4416 - y1_output_loss: 0.1534 - y2_output_loss: 0.2882 - y1_output_root_mean_squared_error: 0.3917 - y2_output_root_mean_squared_error: 0.5369 - val_loss: 2.4858 - val_y1_output_loss: 0.5380 - val_y2_output_loss: 1.9477 - val_y1_output_root_mean_squared_error: 0.7335 - val_y2_output_root_mean_squared_error: 1.3956
# Epoch 491/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4674 - y1_output_loss: 0.1351 - y2_output_loss: 0.3323 - y1_output_root_mean_squared_error: 0.3675 - y2_output_root_mean_squared_error: 0.5765 - val_loss: 0.9983 - val_y1_output_loss: 0.1770 - val_y2_output_loss: 0.8212 - val_y1_output_root_mean_squared_error: 0.4207 - val_y2_output_root_mean_squared_error: 0.9062
# Epoch 492/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3050 - y1_output_loss: 0.1112 - y2_output_loss: 0.1938 - y1_output_root_mean_squared_error: 0.3335 - y2_output_root_mean_squared_error: 0.4403 - val_loss: 1.0160 - val_y1_output_loss: 0.1642 - val_y2_output_loss: 0.8518 - val_y1_output_root_mean_squared_error: 0.4052 - val_y2_output_root_mean_squared_error: 0.9229
# Epoch 493/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.1086 - y1_output_loss: 0.2485 - y2_output_loss: 0.8601 - y1_output_root_mean_squared_error: 0.4985 - y2_output_root_mean_squared_error: 0.9274 - val_loss: 1.8356 - val_y1_output_loss: 0.1896 - val_y2_output_loss: 1.6460 - val_y1_output_root_mean_squared_error: 0.4355 - val_y2_output_root_mean_squared_error: 1.2830
# Epoch 494/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4880 - y1_output_loss: 0.1617 - y2_output_loss: 0.3264 - y1_output_root_mean_squared_error: 0.4021 - y2_output_root_mean_squared_error: 0.5713 - val_loss: 0.9754 - val_y1_output_loss: 0.1555 - val_y2_output_loss: 0.8199 - val_y1_output_root_mean_squared_error: 0.3943 - val_y2_output_root_mean_squared_error: 0.9055
# Epoch 495/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3788 - y1_output_loss: 0.1168 - y2_output_loss: 0.2619 - y1_output_root_mean_squared_error: 0.3418 - y2_output_root_mean_squared_error: 0.5118 - val_loss: 1.0862 - val_y1_output_loss: 0.1941 - val_y2_output_loss: 0.8921 - val_y1_output_root_mean_squared_error: 0.4405 - val_y2_output_root_mean_squared_error: 0.9445
# Epoch 496/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4634 - y1_output_loss: 0.1392 - y2_output_loss: 0.3242 - y1_output_root_mean_squared_error: 0.3731 - y2_output_root_mean_squared_error: 0.5694 - val_loss: 1.0254 - val_y1_output_loss: 0.1695 - val_y2_output_loss: 0.8559 - val_y1_output_root_mean_squared_error: 0.4117 - val_y2_output_root_mean_squared_error: 0.9252
# Epoch 497/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3393 - y1_output_loss: 0.1096 - y2_output_loss: 0.2297 - y1_output_root_mean_squared_error: 0.3311 - y2_output_root_mean_squared_error: 0.4792 - val_loss: 1.2211 - val_y1_output_loss: 0.2417 - val_y2_output_loss: 0.9794 - val_y1_output_root_mean_squared_error: 0.4916 - val_y2_output_root_mean_squared_error: 0.9896
# Epoch 498/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5103 - y1_output_loss: 0.1328 - y2_output_loss: 0.3775 - y1_output_root_mean_squared_error: 0.3644 - y2_output_root_mean_squared_error: 0.6144 - val_loss: 1.1085 - val_y1_output_loss: 0.2090 - val_y2_output_loss: 0.8994 - val_y1_output_root_mean_squared_error: 0.4572 - val_y2_output_root_mean_squared_error: 0.9484
# Epoch 499/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4162 - y1_output_loss: 0.1416 - y2_output_loss: 0.2747 - y1_output_root_mean_squared_error: 0.3762 - y2_output_root_mean_squared_error: 0.5241 - val_loss: 1.2816 - val_y1_output_loss: 0.2075 - val_y2_output_loss: 1.0741 - val_y1_output_root_mean_squared_error: 0.4555 - val_y2_output_root_mean_squared_error: 1.0364
# Epoch 500/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5631 - y1_output_loss: 0.1523 - y2_output_loss: 0.4108 - y1_output_root_mean_squared_error: 0.3902 - y2_output_root_mean_squared_error: 0.6409 - val_loss: 1.3122 - val_y1_output_loss: 0.2918 - val_y2_output_loss: 1.0203 - val_y1_output_root_mean_squared_error: 0.5402 - val_y2_output_root_mean_squared_error: 1.0101

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3149 - y1_output_loss: 0.2933 - y2_output_loss: 1.0216 - y1_output_root_mean_squared_error: 0.5415 - y2_output_root_mean_squared_error: 1.0108
# Loss = 1.3149001598358154, Y1_loss = 0.2932550013065338, Y1_mse = 0.5415302515029907, Y2_loss = 1.021645188331604, Y2_mse = 1.0107645988464355

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)

# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 897us/sample - loss: 246.7535 - y1_output_loss: 113.4209 - y2_output_loss: 131.1446 - y1_output_root_mean_squared_error: 10.6975 - y2_output_root_mean_squared_error: 11.5029 - val_loss: 77.0858 - val_y1_output_loss: 34.8019 - val_y2_output_loss: 41.8894 - val_y1_output_root_mean_squared_error: 5.9282 - val_y2_output_root_mean_squared_error: 6.4762
# Epoch 2/500
# 614/614 [==============================] - 0s 140us/sample - loss: 34.8622 - y1_output_loss: 13.2102 - y2_output_loss: 21.4857 - y1_output_root_mean_squared_error: 3.6457 - y2_output_root_mean_squared_error: 4.6444 - val_loss: 25.6245 - val_y1_output_loss: 10.9665 - val_y2_output_loss: 15.5804 - val_y1_output_root_mean_squared_error: 3.2913 - val_y2_output_root_mean_squared_error: 3.8460
# Epoch 3/500
# 614/614 [==============================] - 0s 130us/sample - loss: 23.9017 - y1_output_loss: 10.0148 - y2_output_loss: 13.6771 - y1_output_root_mean_squared_error: 3.1792 - y2_output_root_mean_squared_error: 3.7141 - val_loss: 22.2746 - val_y1_output_loss: 9.1818 - val_y2_output_loss: 14.9418 - val_y1_output_root_mean_squared_error: 2.9782 - val_y2_output_root_mean_squared_error: 3.6613
# Epoch 4/500
# 614/614 [==============================] - 0s 127us/sample - loss: 22.2949 - y1_output_loss: 9.1891 - y2_output_loss: 13.2653 - y1_output_root_mean_squared_error: 3.0128 - y2_output_root_mean_squared_error: 3.6356 - val_loss: 52.4942 - val_y1_output_loss: 13.0005 - val_y2_output_loss: 42.8584 - val_y1_output_root_mean_squared_error: 3.5310 - val_y2_output_root_mean_squared_error: 6.3266
# Epoch 5/500
# 614/614 [==============================] - 0s 132us/sample - loss: 19.6816 - y1_output_loss: 8.2349 - y2_output_loss: 11.5059 - y1_output_root_mean_squared_error: 2.8594 - y2_output_root_mean_squared_error: 3.3919 - val_loss: 24.4906 - val_y1_output_loss: 10.6693 - val_y2_output_loss: 15.2179 - val_y1_output_root_mean_squared_error: 3.2330 - val_y2_output_root_mean_squared_error: 3.7468
# Epoch 6/500
# 614/614 [==============================] - 0s 139us/sample - loss: 24.8805 - y1_output_loss: 9.6094 - y2_output_loss: 15.5464 - y1_output_root_mean_squared_error: 3.0898 - y2_output_root_mean_squared_error: 3.9158 - val_loss: 76.3239 - val_y1_output_loss: 18.8926 - val_y2_output_loss: 55.1443 - val_y1_output_root_mean_squared_error: 4.4246 - val_y2_output_root_mean_squared_error: 7.5331
# Epoch 7/500
# 614/614 [==============================] - 0s 126us/sample - loss: 20.6063 - y1_output_loss: 8.5104 - y2_output_loss: 12.0827 - y1_output_root_mean_squared_error: 2.9201 - y2_output_root_mean_squared_error: 3.4755 - val_loss: 33.2985 - val_y1_output_loss: 11.1655 - val_y2_output_loss: 25.5443 - val_y1_output_root_mean_squared_error: 3.2205 - val_y2_output_root_mean_squared_error: 4.7882
# Epoch 8/500
# 614/614 [==============================] - 0s 129us/sample - loss: 23.8301 - y1_output_loss: 8.7392 - y2_output_loss: 14.9255 - y1_output_root_mean_squared_error: 2.9678 - y2_output_root_mean_squared_error: 3.8758 - val_loss: 22.3593 - val_y1_output_loss: 8.0621 - val_y2_output_loss: 16.3454 - val_y1_output_root_mean_squared_error: 2.7608 - val_y2_output_root_mean_squared_error: 3.8389
# Epoch 9/500
# 614/614 [==============================] - 0s 126us/sample - loss: 19.9871 - y1_output_loss: 7.9288 - y2_output_loss: 11.8786 - y1_output_root_mean_squared_error: 2.8284 - y2_output_root_mean_squared_error: 3.4623 - val_loss: 20.6046 - val_y1_output_loss: 7.6844 - val_y2_output_loss: 14.5952 - val_y1_output_root_mean_squared_error: 2.7174 - val_y2_output_root_mean_squared_error: 3.6360
# Epoch 10/500
# 614/614 [==============================] - 0s 127us/sample - loss: 20.1614 - y1_output_loss: 7.6184 - y2_output_loss: 12.4477 - y1_output_root_mean_squared_error: 2.7686 - y2_output_root_mean_squared_error: 3.5350 - val_loss: 29.9460 - val_y1_output_loss: 11.5016 - val_y2_output_loss: 17.6163 - val_y1_output_root_mean_squared_error: 3.4512 - val_y2_output_root_mean_squared_error: 4.2467
# Epoch 11/500
# 614/614 [==============================] - 0s 125us/sample - loss: 22.2639 - y1_output_loss: 8.2527 - y2_output_loss: 13.8689 - y1_output_root_mean_squared_error: 2.8844 - y2_output_root_mean_squared_error: 3.7342 - val_loss: 20.6842 - val_y1_output_loss: 7.8285 - val_y2_output_loss: 13.3239 - val_y1_output_root_mean_squared_error: 2.7860 - val_y2_output_root_mean_squared_error: 3.5947
# Epoch 12/500
# 614/614 [==============================] - 0s 126us/sample - loss: 17.8035 - y1_output_loss: 7.2871 - y2_output_loss: 10.3653 - y1_output_root_mean_squared_error: 2.7114 - y2_output_root_mean_squared_error: 3.2329 - val_loss: 17.5600 - val_y1_output_loss: 6.7950 - val_y2_output_loss: 11.9371 - val_y1_output_root_mean_squared_error: 2.5515 - val_y2_output_root_mean_squared_error: 3.3241
# Epoch 13/500
# 614/614 [==============================] - 0s 126us/sample - loss: 18.3632 - y1_output_loss: 7.4724 - y2_output_loss: 10.8646 - y1_output_root_mean_squared_error: 2.7417 - y2_output_root_mean_squared_error: 3.2934 - val_loss: 35.6243 - val_y1_output_loss: 9.5983 - val_y2_output_loss: 25.6243 - val_y1_output_root_mean_squared_error: 3.1147 - val_y2_output_root_mean_squared_error: 5.0915
# Epoch 14/500
# 614/614 [==============================] - 0s 126us/sample - loss: 17.5177 - y1_output_loss: 6.8839 - y2_output_loss: 10.6507 - y1_output_root_mean_squared_error: 2.6172 - y2_output_root_mean_squared_error: 3.2661 - val_loss: 22.2722 - val_y1_output_loss: 7.9369 - val_y2_output_loss: 14.3347 - val_y1_output_root_mean_squared_error: 2.8332 - val_y2_output_root_mean_squared_error: 3.7743
# Epoch 15/500
# 614/614 [==============================] - 0s 125us/sample - loss: 15.3411 - y1_output_loss: 6.1693 - y2_output_loss: 9.0562 - y1_output_root_mean_squared_error: 2.4934 - y2_output_root_mean_squared_error: 3.0206 - val_loss: 16.5419 - val_y1_output_loss: 6.0798 - val_y2_output_loss: 11.7552 - val_y1_output_root_mean_squared_error: 2.4095 - val_y2_output_root_mean_squared_error: 3.2766
# Epoch 16/500
# 614/614 [==============================] - 0s 126us/sample - loss: 17.2370 - y1_output_loss: 6.4163 - y2_output_loss: 11.0627 - y1_output_root_mean_squared_error: 2.5228 - y2_output_root_mean_squared_error: 3.2973 - val_loss: 40.2355 - val_y1_output_loss: 9.9604 - val_y2_output_loss: 29.3095 - val_y1_output_root_mean_squared_error: 3.1975 - val_y2_output_root_mean_squared_error: 5.4783
# Epoch 17/500
# 614/614 [==============================] - 0s 127us/sample - loss: 15.9678 - y1_output_loss: 6.3840 - y2_output_loss: 9.4551 - y1_output_root_mean_squared_error: 2.5374 - y2_output_root_mean_squared_error: 3.0870 - val_loss: 14.9355 - val_y1_output_loss: 5.3387 - val_y2_output_loss: 10.4871 - val_y1_output_root_mean_squared_error: 2.2894 - val_y2_output_root_mean_squared_error: 3.1135
# Epoch 18/500
# 614/614 [==============================] - 0s 128us/sample - loss: 14.7681 - y1_output_loss: 5.9442 - y2_output_loss: 8.9660 - y1_output_root_mean_squared_error: 2.4349 - y2_output_root_mean_squared_error: 2.9731 - val_loss: 14.0057 - val_y1_output_loss: 5.2812 - val_y2_output_loss: 9.6201 - val_y1_output_root_mean_squared_error: 2.2415 - val_y2_output_root_mean_squared_error: 2.9969
# Epoch 19/500
# 614/614 [==============================] - 0s 132us/sample - loss: 14.8850 - y1_output_loss: 6.1751 - y2_output_loss: 8.7754 - y1_output_root_mean_squared_error: 2.4826 - y2_output_root_mean_squared_error: 2.9533 - val_loss: 22.3722 - val_y1_output_loss: 6.7817 - val_y2_output_loss: 15.0023 - val_y1_output_root_mean_squared_error: 2.6455 - val_y2_output_root_mean_squared_error: 3.9209
# Epoch 20/500
# 614/614 [==============================] - 0s 131us/sample - loss: 13.6619 - y1_output_loss: 5.5921 - y2_output_loss: 8.0278 - y1_output_root_mean_squared_error: 2.3638 - y2_output_root_mean_squared_error: 2.8415 - val_loss: 26.0095 - val_y1_output_loss: 8.4311 - val_y2_output_loss: 19.5419 - val_y1_output_root_mean_squared_error: 2.8263 - val_y2_output_root_mean_squared_error: 4.2452
# Epoch 21/500
# 614/614 [==============================] - 0s 126us/sample - loss: 14.9123 - y1_output_loss: 5.7146 - y2_output_loss: 9.1058 - y1_output_root_mean_squared_error: 2.4004 - y2_output_root_mean_squared_error: 3.0250 - val_loss: 13.1492 - val_y1_output_loss: 4.9664 - val_y2_output_loss: 8.4824 - val_y1_output_root_mean_squared_error: 2.2423 - val_y2_output_root_mean_squared_error: 2.8498
# Epoch 22/500
# 614/614 [==============================] - 0s 126us/sample - loss: 13.6699 - y1_output_loss: 5.3222 - y2_output_loss: 8.2484 - y1_output_root_mean_squared_error: 2.3172 - y2_output_root_mean_squared_error: 2.8810 - val_loss: 13.5126 - val_y1_output_loss: 5.0084 - val_y2_output_loss: 8.6141 - val_y1_output_root_mean_squared_error: 2.2592 - val_y2_output_root_mean_squared_error: 2.8998
# Epoch 23/500
# 614/614 [==============================] - 0s 124us/sample - loss: 13.2702 - y1_output_loss: 5.1917 - y2_output_loss: 7.9570 - y1_output_root_mean_squared_error: 2.2888 - y2_output_root_mean_squared_error: 2.8340 - val_loss: 13.3567 - val_y1_output_loss: 4.4714 - val_y2_output_loss: 9.7781 - val_y1_output_root_mean_squared_error: 2.0886 - val_y2_output_root_mean_squared_error: 2.9990
# Epoch 24/500
# 614/614 [==============================] - 0s 127us/sample - loss: 12.6218 - y1_output_loss: 4.7421 - y2_output_loss: 7.8015 - y1_output_root_mean_squared_error: 2.1802 - y2_output_root_mean_squared_error: 2.8051 - val_loss: 17.2520 - val_y1_output_loss: 6.5638 - val_y2_output_loss: 10.5460 - val_y1_output_root_mean_squared_error: 2.5928 - val_y2_output_root_mean_squared_error: 3.2449
# Epoch 25/500
# 614/614 [==============================] - 0s 125us/sample - loss: 13.4560 - y1_output_loss: 5.2395 - y2_output_loss: 8.1430 - y1_output_root_mean_squared_error: 2.2974 - y2_output_root_mean_squared_error: 2.8597 - val_loss: 13.8767 - val_y1_output_loss: 5.5827 - val_y2_output_loss: 8.4921 - val_y1_output_root_mean_squared_error: 2.3764 - val_y2_output_root_mean_squared_error: 2.8687
# Epoch 26/500
# 614/614 [==============================] - 0s 134us/sample - loss: 11.8812 - y1_output_loss: 4.6223 - y2_output_loss: 7.3011 - y1_output_root_mean_squared_error: 2.1530 - y2_output_root_mean_squared_error: 2.6918 - val_loss: 50.4442 - val_y1_output_loss: 12.1733 - val_y2_output_loss: 37.4829 - val_y1_output_root_mean_squared_error: 3.5200 - val_y2_output_root_mean_squared_error: 6.1688
# Epoch 27/500
# 614/614 [==============================] - 0s 133us/sample - loss: 12.9963 - y1_output_loss: 4.9747 - y2_output_loss: 7.9489 - y1_output_root_mean_squared_error: 2.2312 - y2_output_root_mean_squared_error: 2.8317 - val_loss: 14.8324 - val_y1_output_loss: 5.6764 - val_y2_output_loss: 10.0049 - val_y1_output_root_mean_squared_error: 2.3432 - val_y2_output_root_mean_squared_error: 3.0564
# Epoch 28/500
# 614/614 [==============================] - 0s 125us/sample - loss: 10.7062 - y1_output_loss: 4.4746 - y2_output_loss: 6.3429 - y1_output_root_mean_squared_error: 2.1104 - y2_output_root_mean_squared_error: 2.5004 - val_loss: 27.7384 - val_y1_output_loss: 8.2666 - val_y2_output_loss: 19.1149 - val_y1_output_root_mean_squared_error: 2.8958 - val_y2_output_root_mean_squared_error: 4.3992
# Epoch 29/500
# 614/614 [==============================] - 0s 125us/sample - loss: 13.6410 - y1_output_loss: 5.0426 - y2_output_loss: 8.5588 - y1_output_root_mean_squared_error: 2.2391 - y2_output_root_mean_squared_error: 2.9373 - val_loss: 15.4086 - val_y1_output_loss: 5.6242 - val_y2_output_loss: 10.7696 - val_y1_output_root_mean_squared_error: 2.3260 - val_y2_output_root_mean_squared_error: 3.1620
# Epoch 30/500
# 614/614 [==============================] - 0s 125us/sample - loss: 11.5571 - y1_output_loss: 4.3538 - y2_output_loss: 7.3492 - y1_output_root_mean_squared_error: 2.0634 - y2_output_root_mean_squared_error: 2.7017 - val_loss: 31.5478 - val_y1_output_loss: 8.8592 - val_y2_output_loss: 24.6420 - val_y1_output_root_mean_squared_error: 2.9160 - val_y2_output_root_mean_squared_error: 4.8005
# Epoch 31/500
# 614/614 [==============================] - 0s 123us/sample - loss: 11.6142 - y1_output_loss: 4.3880 - y2_output_loss: 7.1415 - y1_output_root_mean_squared_error: 2.1043 - y2_output_root_mean_squared_error: 2.6807 - val_loss: 10.4650 - val_y1_output_loss: 3.5401 - val_y2_output_loss: 7.0153 - val_y1_output_root_mean_squared_error: 1.9014 - val_y2_output_root_mean_squared_error: 2.6172
# Epoch 32/500
# 614/614 [==============================] - 0s 122us/sample - loss: 10.1235 - y1_output_loss: 3.9164 - y2_output_loss: 6.3615 - y1_output_root_mean_squared_error: 1.9843 - y2_output_root_mean_squared_error: 2.4872 - val_loss: 37.7628 - val_y1_output_loss: 6.6248 - val_y2_output_loss: 30.6297 - val_y1_output_root_mean_squared_error: 2.5973 - val_y2_output_root_mean_squared_error: 5.5693
# Epoch 33/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.7517 - y1_output_loss: 3.8288 - y2_output_loss: 6.8275 - y1_output_root_mean_squared_error: 1.9658 - y2_output_root_mean_squared_error: 2.6243 - val_loss: 9.2227 - val_y1_output_loss: 3.0196 - val_y2_output_loss: 6.4453 - val_y1_output_root_mean_squared_error: 1.7489 - val_y2_output_root_mean_squared_error: 2.4827
# Epoch 34/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.7725 - y1_output_loss: 3.4088 - y2_output_loss: 5.3391 - y1_output_root_mean_squared_error: 1.8442 - y2_output_root_mean_squared_error: 2.3176 - val_loss: 17.6583 - val_y1_output_loss: 6.4655 - val_y2_output_loss: 12.4870 - val_y1_output_root_mean_squared_error: 2.4861 - val_y2_output_root_mean_squared_error: 3.3879
# Epoch 35/500
# 614/614 [==============================] - 0s 124us/sample - loss: 8.7622 - y1_output_loss: 3.2374 - y2_output_loss: 5.6271 - y1_output_root_mean_squared_error: 1.8017 - y2_output_root_mean_squared_error: 2.3487 - val_loss: 13.3162 - val_y1_output_loss: 3.3140 - val_y2_output_loss: 9.7494 - val_y1_output_root_mean_squared_error: 1.8427 - val_y2_output_root_mean_squared_error: 3.1497
# Epoch 36/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.4969 - y1_output_loss: 3.1814 - y2_output_loss: 5.2525 - y1_output_root_mean_squared_error: 1.7903 - y2_output_root_mean_squared_error: 2.3004 - val_loss: 11.1077 - val_y1_output_loss: 3.3190 - val_y2_output_loss: 8.1652 - val_y1_output_root_mean_squared_error: 1.8275 - val_y2_output_root_mean_squared_error: 2.7871
# Epoch 37/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.9734 - y1_output_loss: 3.3173 - y2_output_loss: 6.6284 - y1_output_root_mean_squared_error: 1.8124 - y2_output_root_mean_squared_error: 2.5863 - val_loss: 14.5284 - val_y1_output_loss: 4.3452 - val_y2_output_loss: 11.1924 - val_y1_output_root_mean_squared_error: 2.0474 - val_y2_output_root_mean_squared_error: 3.2151
# Epoch 38/500
# 614/614 [==============================] - 0s 124us/sample - loss: 9.4011 - y1_output_loss: 3.0035 - y2_output_loss: 6.3780 - y1_output_root_mean_squared_error: 1.7375 - y2_output_root_mean_squared_error: 2.5263 - val_loss: 10.3831 - val_y1_output_loss: 3.6272 - val_y2_output_loss: 6.6617 - val_y1_output_root_mean_squared_error: 1.9362 - val_y2_output_root_mean_squared_error: 2.5757
# Epoch 39/500
# 614/614 [==============================] - 0s 135us/sample - loss: 12.1905 - y1_output_loss: 4.3236 - y2_output_loss: 7.7701 - y1_output_root_mean_squared_error: 2.0855 - y2_output_root_mean_squared_error: 2.8002 - val_loss: 8.7562 - val_y1_output_loss: 2.8138 - val_y2_output_loss: 6.2412 - val_y1_output_root_mean_squared_error: 1.6967 - val_y2_output_root_mean_squared_error: 2.4243
# Epoch 40/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.5200 - y1_output_loss: 2.7799 - y2_output_loss: 4.9305 - y1_output_root_mean_squared_error: 1.6477 - y2_output_root_mean_squared_error: 2.1920 - val_loss: 36.5423 - val_y1_output_loss: 9.8684 - val_y2_output_loss: 25.6280 - val_y1_output_root_mean_squared_error: 3.1920 - val_y2_output_root_mean_squared_error: 5.1335
# Epoch 41/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.9192 - y1_output_loss: 2.8432 - y2_output_loss: 6.1184 - y1_output_root_mean_squared_error: 1.6872 - y2_output_root_mean_squared_error: 2.4643 - val_loss: 28.2170 - val_y1_output_loss: 6.9343 - val_y2_output_loss: 20.5088 - val_y1_output_root_mean_squared_error: 2.6749 - val_y2_output_root_mean_squared_error: 4.5893
# Epoch 42/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.5779 - y1_output_loss: 2.6801 - y2_output_loss: 4.9253 - y1_output_root_mean_squared_error: 1.6360 - y2_output_root_mean_squared_error: 2.2139 - val_loss: 9.0473 - val_y1_output_loss: 2.9177 - val_y2_output_loss: 6.5052 - val_y1_output_root_mean_squared_error: 1.7360 - val_y2_output_root_mean_squared_error: 2.4564
# Epoch 43/500
# 614/614 [==============================] - 0s 132us/sample - loss: 14.1763 - y1_output_loss: 4.3472 - y2_output_loss: 9.7289 - y1_output_root_mean_squared_error: 2.0892 - y2_output_root_mean_squared_error: 3.1323 - val_loss: 10.0999 - val_y1_output_loss: 3.7129 - val_y2_output_loss: 6.8979 - val_y1_output_root_mean_squared_error: 1.9168 - val_y2_output_root_mean_squared_error: 2.5349
# Epoch 44/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.2294 - y1_output_loss: 2.7005 - y2_output_loss: 6.4470 - y1_output_root_mean_squared_error: 1.6503 - y2_output_root_mean_squared_error: 2.5506 - val_loss: 7.5931 - val_y1_output_loss: 2.3875 - val_y2_output_loss: 5.3282 - val_y1_output_root_mean_squared_error: 1.5656 - val_y2_output_root_mean_squared_error: 2.2676
# Epoch 45/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.0880 - y1_output_loss: 2.5379 - y2_output_loss: 4.5080 - y1_output_root_mean_squared_error: 1.5945 - y2_output_root_mean_squared_error: 2.1320 - val_loss: 7.7263 - val_y1_output_loss: 2.6020 - val_y2_output_loss: 5.4917 - val_y1_output_root_mean_squared_error: 1.6100 - val_y2_output_root_mean_squared_error: 2.2659
# Epoch 46/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.4365 - y1_output_loss: 2.9173 - y2_output_loss: 6.5121 - y1_output_root_mean_squared_error: 1.7111 - y2_output_root_mean_squared_error: 2.5512 - val_loss: 8.2288 - val_y1_output_loss: 2.1563 - val_y2_output_loss: 6.1136 - val_y1_output_root_mean_squared_error: 1.4745 - val_y2_output_root_mean_squared_error: 2.4606
# Epoch 47/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.3910 - y1_output_loss: 2.1117 - y2_output_loss: 4.2502 - y1_output_root_mean_squared_error: 1.4528 - y2_output_root_mean_squared_error: 2.0689 - val_loss: 8.1025 - val_y1_output_loss: 2.8057 - val_y2_output_loss: 5.5833 - val_y1_output_root_mean_squared_error: 1.6973 - val_y2_output_root_mean_squared_error: 2.2851
# Epoch 48/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.2091 - y1_output_loss: 1.8636 - y2_output_loss: 4.3056 - y1_output_root_mean_squared_error: 1.3683 - y2_output_root_mean_squared_error: 2.0825 - val_loss: 6.4939 - val_y1_output_loss: 1.8380 - val_y2_output_loss: 4.8425 - val_y1_output_root_mean_squared_error: 1.3704 - val_y2_output_root_mean_squared_error: 2.1485
# Epoch 49/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.1750 - y1_output_loss: 2.1724 - y2_output_loss: 4.1095 - y1_output_root_mean_squared_error: 1.4451 - y2_output_root_mean_squared_error: 2.0216 - val_loss: 7.0110 - val_y1_output_loss: 2.0546 - val_y2_output_loss: 5.0557 - val_y1_output_root_mean_squared_error: 1.4513 - val_y2_output_root_mean_squared_error: 2.2146
# Epoch 50/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.6579 - y1_output_loss: 2.0259 - y2_output_loss: 4.5887 - y1_output_root_mean_squared_error: 1.4263 - y2_output_root_mean_squared_error: 2.1502 - val_loss: 6.6177 - val_y1_output_loss: 2.0261 - val_y2_output_loss: 4.9125 - val_y1_output_root_mean_squared_error: 1.4136 - val_y2_output_root_mean_squared_error: 2.1493
# Epoch 51/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.8114 - y1_output_loss: 2.0197 - y2_output_loss: 4.7634 - y1_output_root_mean_squared_error: 1.4183 - y2_output_root_mean_squared_error: 2.1908 - val_loss: 10.6319 - val_y1_output_loss: 2.6342 - val_y2_output_loss: 8.7678 - val_y1_output_root_mean_squared_error: 1.6006 - val_y2_output_root_mean_squared_error: 2.8408
# Epoch 52/500
# 614/614 [==============================] - 0s 123us/sample - loss: 6.1344 - y1_output_loss: 1.8767 - y2_output_loss: 4.2044 - y1_output_root_mean_squared_error: 1.3750 - y2_output_root_mean_squared_error: 2.0600 - val_loss: 6.4486 - val_y1_output_loss: 1.8762 - val_y2_output_loss: 4.9236 - val_y1_output_root_mean_squared_error: 1.3748 - val_y2_output_root_mean_squared_error: 2.1351
# Epoch 53/500
# 614/614 [==============================] - 0s 124us/sample - loss: 5.3033 - y1_output_loss: 1.5251 - y2_output_loss: 3.8253 - y1_output_root_mean_squared_error: 1.2386 - y2_output_root_mean_squared_error: 1.9414 - val_loss: 11.4792 - val_y1_output_loss: 2.0367 - val_y2_output_loss: 10.2911 - val_y1_output_root_mean_squared_error: 1.4067 - val_y2_output_root_mean_squared_error: 3.0823
# Epoch 54/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.4674 - y1_output_loss: 2.4886 - y2_output_loss: 5.9160 - y1_output_root_mean_squared_error: 1.5801 - y2_output_root_mean_squared_error: 2.4435 - val_loss: 6.5577 - val_y1_output_loss: 1.6638 - val_y2_output_loss: 5.3283 - val_y1_output_root_mean_squared_error: 1.3015 - val_y2_output_root_mean_squared_error: 2.2054
# Epoch 55/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.1339 - y1_output_loss: 1.6569 - y2_output_loss: 4.4387 - y1_output_root_mean_squared_error: 1.2883 - y2_output_root_mean_squared_error: 2.1152 - val_loss: 6.7284 - val_y1_output_loss: 1.7009 - val_y2_output_loss: 5.4517 - val_y1_output_root_mean_squared_error: 1.3092 - val_y2_output_root_mean_squared_error: 2.2393
# Epoch 56/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.2613 - y1_output_loss: 1.6460 - y2_output_loss: 3.6501 - y1_output_root_mean_squared_error: 1.2804 - y2_output_root_mean_squared_error: 1.9031 - val_loss: 5.6095 - val_y1_output_loss: 1.6641 - val_y2_output_loss: 4.2592 - val_y1_output_root_mean_squared_error: 1.2767 - val_y2_output_root_mean_squared_error: 1.9949
# Epoch 57/500
# 614/614 [==============================] - 0s 126us/sample - loss: 7.0132 - y1_output_loss: 2.0909 - y2_output_loss: 4.8637 - y1_output_root_mean_squared_error: 1.4516 - y2_output_root_mean_squared_error: 2.2150 - val_loss: 6.7722 - val_y1_output_loss: 1.9990 - val_y2_output_loss: 4.9562 - val_y1_output_root_mean_squared_error: 1.4245 - val_y2_output_root_mean_squared_error: 2.1778
# Epoch 58/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.4013 - y1_output_loss: 1.5015 - y2_output_loss: 3.8887 - y1_output_root_mean_squared_error: 1.2246 - y2_output_root_mean_squared_error: 1.9753 - val_loss: 7.7572 - val_y1_output_loss: 1.2248 - val_y2_output_loss: 7.2090 - val_y1_output_root_mean_squared_error: 1.1061 - val_y2_output_root_mean_squared_error: 2.5561
# Epoch 59/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.2062 - y1_output_loss: 1.8119 - y2_output_loss: 4.4624 - y1_output_root_mean_squared_error: 1.3419 - y2_output_root_mean_squared_error: 2.0990 - val_loss: 18.5475 - val_y1_output_loss: 5.7082 - val_y2_output_loss: 12.4284 - val_y1_output_root_mean_squared_error: 2.4258 - val_y2_output_root_mean_squared_error: 3.5585
# Epoch 60/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.9756 - y1_output_loss: 1.3080 - y2_output_loss: 3.6394 - y1_output_root_mean_squared_error: 1.1447 - y2_output_root_mean_squared_error: 1.9145 - val_loss: 4.6186 - val_y1_output_loss: 1.0575 - val_y2_output_loss: 3.7697 - val_y1_output_root_mean_squared_error: 1.0343 - val_y2_output_root_mean_squared_error: 1.8838
# Epoch 61/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.5047 - y1_output_loss: 1.2671 - y2_output_loss: 3.2894 - y1_output_root_mean_squared_error: 1.1258 - y2_output_root_mean_squared_error: 1.7993 - val_loss: 6.3978 - val_y1_output_loss: 1.2573 - val_y2_output_loss: 5.0773 - val_y1_output_root_mean_squared_error: 1.1370 - val_y2_output_root_mean_squared_error: 2.2594
# Epoch 62/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.1327 - y1_output_loss: 1.0954 - y2_output_loss: 3.0608 - y1_output_root_mean_squared_error: 1.0493 - y2_output_root_mean_squared_error: 1.7412 - val_loss: 4.6469 - val_y1_output_loss: 1.0112 - val_y2_output_loss: 3.6724 - val_y1_output_root_mean_squared_error: 1.0109 - val_y2_output_root_mean_squared_error: 1.9039
# Epoch 63/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.7021 - y1_output_loss: 1.8591 - y2_output_loss: 4.8241 - y1_output_root_mean_squared_error: 1.3558 - y2_output_root_mean_squared_error: 2.2055 - val_loss: 6.3038 - val_y1_output_loss: 1.8637 - val_y2_output_loss: 4.5532 - val_y1_output_root_mean_squared_error: 1.3840 - val_y2_output_root_mean_squared_error: 2.0949
# Epoch 64/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.5585 - y1_output_loss: 1.1148 - y2_output_loss: 3.4205 - y1_output_root_mean_squared_error: 1.0577 - y2_output_root_mean_squared_error: 1.8547 - val_loss: 5.0925 - val_y1_output_loss: 1.4799 - val_y2_output_loss: 3.7148 - val_y1_output_root_mean_squared_error: 1.2334 - val_y2_output_root_mean_squared_error: 1.8898
# Epoch 65/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.0663 - y1_output_loss: 1.0907 - y2_output_loss: 2.9716 - y1_output_root_mean_squared_error: 1.0484 - y2_output_root_mean_squared_error: 1.7225 - val_loss: 4.9476 - val_y1_output_loss: 1.2882 - val_y2_output_loss: 3.6976 - val_y1_output_root_mean_squared_error: 1.1487 - val_y2_output_root_mean_squared_error: 1.9047
# Epoch 66/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.0344 - y1_output_loss: 1.1527 - y2_output_loss: 2.8586 - y1_output_root_mean_squared_error: 1.0751 - y2_output_root_mean_squared_error: 1.6966 - val_loss: 4.1555 - val_y1_output_loss: 0.8114 - val_y2_output_loss: 3.6331 - val_y1_output_root_mean_squared_error: 0.9049 - val_y2_output_root_mean_squared_error: 1.8267
# Epoch 67/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.2677 - y1_output_loss: 1.0785 - y2_output_loss: 3.1615 - y1_output_root_mean_squared_error: 1.0397 - y2_output_root_mean_squared_error: 1.7851 - val_loss: 3.9948 - val_y1_output_loss: 0.8079 - val_y2_output_loss: 3.4763 - val_y1_output_root_mean_squared_error: 0.9011 - val_y2_output_root_mean_squared_error: 1.7841
# Epoch 68/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.1044 - y1_output_loss: 1.0320 - y2_output_loss: 3.0438 - y1_output_root_mean_squared_error: 1.0172 - y2_output_root_mean_squared_error: 1.7521 - val_loss: 5.9397 - val_y1_output_loss: 1.5300 - val_y2_output_loss: 4.3786 - val_y1_output_root_mean_squared_error: 1.2562 - val_y2_output_root_mean_squared_error: 2.0884
# Epoch 69/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.5733 - y1_output_loss: 1.0323 - y2_output_loss: 3.5171 - y1_output_root_mean_squared_error: 1.0179 - y2_output_root_mean_squared_error: 1.8808 - val_loss: 4.0994 - val_y1_output_loss: 1.0670 - val_y2_output_loss: 3.2166 - val_y1_output_root_mean_squared_error: 1.0497 - val_y2_output_root_mean_squared_error: 1.7314
# Epoch 70/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.9661 - y1_output_loss: 1.0254 - y2_output_loss: 2.9346 - y1_output_root_mean_squared_error: 1.0134 - y2_output_root_mean_squared_error: 1.7144 - val_loss: 5.2620 - val_y1_output_loss: 0.7300 - val_y2_output_loss: 4.9569 - val_y1_output_root_mean_squared_error: 0.8478 - val_y2_output_root_mean_squared_error: 2.1315
# Epoch 71/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.3593 - y1_output_loss: 0.9661 - y2_output_loss: 3.4835 - y1_output_root_mean_squared_error: 0.9798 - y2_output_root_mean_squared_error: 1.8437 - val_loss: 12.7549 - val_y1_output_loss: 2.2606 - val_y2_output_loss: 11.2511 - val_y1_output_root_mean_squared_error: 1.4850 - val_y2_output_root_mean_squared_error: 3.2480
# Epoch 72/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.4160 - y1_output_loss: 0.8071 - y2_output_loss: 2.7256 - y1_output_root_mean_squared_error: 0.8881 - y2_output_root_mean_squared_error: 1.6209 - val_loss: 25.1274 - val_y1_output_loss: 6.3643 - val_y2_output_loss: 18.7251 - val_y1_output_root_mean_squared_error: 2.5198 - val_y2_output_root_mean_squared_error: 4.3333
# Epoch 73/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.3506 - y1_output_loss: 1.8684 - y2_output_loss: 4.4945 - y1_output_root_mean_squared_error: 1.3718 - y2_output_root_mean_squared_error: 2.1139 - val_loss: 10.7156 - val_y1_output_loss: 4.5370 - val_y2_output_loss: 6.5230 - val_y1_output_root_mean_squared_error: 2.1609 - val_y2_output_root_mean_squared_error: 2.4589
# Epoch 74/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.2375 - y1_output_loss: 1.4331 - y2_output_loss: 4.7454 - y1_output_root_mean_squared_error: 1.2028 - y2_output_root_mean_squared_error: 2.1888 - val_loss: 8.4295 - val_y1_output_loss: 3.1463 - val_y2_output_loss: 5.1259 - val_y1_output_root_mean_squared_error: 1.7918 - val_y2_output_root_mean_squared_error: 2.2845
# Epoch 75/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.5178 - y1_output_loss: 1.3044 - y2_output_loss: 4.1648 - y1_output_root_mean_squared_error: 1.1471 - y2_output_root_mean_squared_error: 2.0499 - val_loss: 3.2229 - val_y1_output_loss: 0.5935 - val_y2_output_loss: 2.8256 - val_y1_output_root_mean_squared_error: 0.7691 - val_y2_output_root_mean_squared_error: 1.6221
# Epoch 76/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.5238 - y1_output_loss: 1.1894 - y2_output_loss: 3.3300 - y1_output_root_mean_squared_error: 1.0953 - y2_output_root_mean_squared_error: 1.8232 - val_loss: 6.3493 - val_y1_output_loss: 1.7414 - val_y2_output_loss: 4.5641 - val_y1_output_root_mean_squared_error: 1.3348 - val_y2_output_root_mean_squared_error: 2.1372
# Epoch 77/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.5977 - y1_output_loss: 0.7528 - y2_output_loss: 2.8239 - y1_output_root_mean_squared_error: 0.8694 - y2_output_root_mean_squared_error: 1.6858 - val_loss: 3.6273 - val_y1_output_loss: 0.6943 - val_y2_output_loss: 3.2580 - val_y1_output_root_mean_squared_error: 0.8220 - val_y2_output_root_mean_squared_error: 1.7180
# Epoch 78/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.8944 - y1_output_loss: 0.8885 - y2_output_loss: 2.9814 - y1_output_root_mean_squared_error: 0.9464 - y2_output_root_mean_squared_error: 1.7317 - val_loss: 3.7985 - val_y1_output_loss: 0.9404 - val_y2_output_loss: 2.9472 - val_y1_output_root_mean_squared_error: 0.9846 - val_y2_output_root_mean_squared_error: 1.6820
# Epoch 79/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.1165 - y1_output_loss: 0.8734 - y2_output_loss: 3.2214 - y1_output_root_mean_squared_error: 0.9346 - y2_output_root_mean_squared_error: 1.8008 - val_loss: 4.6567 - val_y1_output_loss: 0.6388 - val_y2_output_loss: 4.3753 - val_y1_output_root_mean_squared_error: 0.8019 - val_y2_output_root_mean_squared_error: 2.0034
# Epoch 80/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.3006 - y1_output_loss: 0.7448 - y2_output_loss: 2.5279 - y1_output_root_mean_squared_error: 0.8662 - y2_output_root_mean_squared_error: 1.5970 - val_loss: 4.0971 - val_y1_output_loss: 0.9674 - val_y2_output_loss: 3.1297 - val_y1_output_root_mean_squared_error: 0.9954 - val_y2_output_root_mean_squared_error: 1.7625
# Epoch 81/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.6360 - y1_output_loss: 0.7518 - y2_output_loss: 2.9376 - y1_output_root_mean_squared_error: 0.8672 - y2_output_root_mean_squared_error: 1.6983 - val_loss: 23.5326 - val_y1_output_loss: 3.3538 - val_y2_output_loss: 21.0787 - val_y1_output_root_mean_squared_error: 1.8205 - val_y2_output_root_mean_squared_error: 4.4965
# Epoch 82/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.3672 - y1_output_loss: 1.5579 - y2_output_loss: 3.8173 - y1_output_root_mean_squared_error: 1.2505 - y2_output_root_mean_squared_error: 1.9502 - val_loss: 4.6954 - val_y1_output_loss: 1.1076 - val_y2_output_loss: 3.6760 - val_y1_output_root_mean_squared_error: 1.0586 - val_y2_output_root_mean_squared_error: 1.8907
# Epoch 83/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.1580 - y1_output_loss: 1.3291 - y2_output_loss: 3.7946 - y1_output_root_mean_squared_error: 1.1530 - y2_output_root_mean_squared_error: 1.9567 - val_loss: 3.1700 - val_y1_output_loss: 0.5601 - val_y2_output_loss: 2.7730 - val_y1_output_root_mean_squared_error: 0.7499 - val_y2_output_root_mean_squared_error: 1.6148
# Epoch 84/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.1157 - y1_output_loss: 0.6706 - y2_output_loss: 2.4254 - y1_output_root_mean_squared_error: 0.8206 - y2_output_root_mean_squared_error: 1.5628 - val_loss: 3.4467 - val_y1_output_loss: 0.6893 - val_y2_output_loss: 3.0211 - val_y1_output_root_mean_squared_error: 0.8221 - val_y2_output_root_mean_squared_error: 1.6646
# Epoch 85/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.3003 - y1_output_loss: 0.7333 - y2_output_loss: 2.5660 - y1_output_root_mean_squared_error: 0.8541 - y2_output_root_mean_squared_error: 1.6034 - val_loss: 4.5844 - val_y1_output_loss: 1.4503 - val_y2_output_loss: 3.1351 - val_y1_output_root_mean_squared_error: 1.2169 - val_y2_output_root_mean_squared_error: 1.7617
# Epoch 86/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.9867 - y1_output_loss: 1.0145 - y2_output_loss: 2.9966 - y1_output_root_mean_squared_error: 1.0066 - y2_output_root_mean_squared_error: 1.7244 - val_loss: 4.2314 - val_y1_output_loss: 1.1136 - val_y2_output_loss: 3.4128 - val_y1_output_root_mean_squared_error: 1.0415 - val_y2_output_root_mean_squared_error: 1.7739
# Epoch 87/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.8364 - y1_output_loss: 0.6877 - y2_output_loss: 2.1305 - y1_output_root_mean_squared_error: 0.8310 - y2_output_root_mean_squared_error: 1.4649 - val_loss: 5.0359 - val_y1_output_loss: 0.5549 - val_y2_output_loss: 4.7326 - val_y1_output_root_mean_squared_error: 0.7525 - val_y2_output_root_mean_squared_error: 2.1142
# Epoch 88/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.0470 - y1_output_loss: 0.5820 - y2_output_loss: 2.4614 - y1_output_root_mean_squared_error: 0.7632 - y2_output_root_mean_squared_error: 1.5699 - val_loss: 8.7733 - val_y1_output_loss: 1.8899 - val_y2_output_loss: 7.0112 - val_y1_output_root_mean_squared_error: 1.3940 - val_y2_output_root_mean_squared_error: 2.6134
# Epoch 89/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.1337 - y1_output_loss: 0.7667 - y2_output_loss: 2.3776 - y1_output_root_mean_squared_error: 0.8687 - y2_output_root_mean_squared_error: 1.5424 - val_loss: 7.7145 - val_y1_output_loss: 2.8366 - val_y2_output_loss: 4.8898 - val_y1_output_root_mean_squared_error: 1.7097 - val_y2_output_root_mean_squared_error: 2.1889
# Epoch 90/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.9625 - y1_output_loss: 0.6759 - y2_output_loss: 2.2715 - y1_output_root_mean_squared_error: 0.8258 - y2_output_root_mean_squared_error: 1.5101 - val_loss: 4.6460 - val_y1_output_loss: 1.1437 - val_y2_output_loss: 3.5046 - val_y1_output_root_mean_squared_error: 1.0724 - val_y2_output_root_mean_squared_error: 1.8697
# Epoch 91/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.8506 - y1_output_loss: 0.5793 - y2_output_loss: 2.2495 - y1_output_root_mean_squared_error: 0.7618 - y2_output_root_mean_squared_error: 1.5068 - val_loss: 3.4744 - val_y1_output_loss: 0.4703 - val_y2_output_loss: 3.0765 - val_y1_output_root_mean_squared_error: 0.6831 - val_y2_output_root_mean_squared_error: 1.7343
# Epoch 92/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.5011 - y1_output_loss: 0.7821 - y2_output_loss: 2.6891 - y1_output_root_mean_squared_error: 0.8877 - y2_output_root_mean_squared_error: 1.6471 - val_loss: 3.1739 - val_y1_output_loss: 0.5329 - val_y2_output_loss: 2.7505 - val_y1_output_root_mean_squared_error: 0.7395 - val_y2_output_root_mean_squared_error: 1.6208
# Epoch 93/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.2173 - y1_output_loss: 0.6350 - y2_output_loss: 2.5622 - y1_output_root_mean_squared_error: 0.7997 - y2_output_root_mean_squared_error: 1.6056 - val_loss: 4.8815 - val_y1_output_loss: 0.9124 - val_y2_output_loss: 4.1917 - val_y1_output_root_mean_squared_error: 0.9566 - val_y2_output_root_mean_squared_error: 1.9916
# Epoch 94/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.0661 - y1_output_loss: 0.5872 - y2_output_loss: 2.4528 - y1_output_root_mean_squared_error: 0.7688 - y2_output_root_mean_squared_error: 1.5732 - val_loss: 2.8337 - val_y1_output_loss: 0.4605 - val_y2_output_loss: 2.5137 - val_y1_output_root_mean_squared_error: 0.6770 - val_y2_output_root_mean_squared_error: 1.5412
# Epoch 95/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.7439 - y1_output_loss: 1.0802 - y2_output_loss: 3.6223 - y1_output_root_mean_squared_error: 1.0438 - y2_output_root_mean_squared_error: 1.9116 - val_loss: 4.6355 - val_y1_output_loss: 1.4282 - val_y2_output_loss: 3.1831 - val_y1_output_root_mean_squared_error: 1.2125 - val_y2_output_root_mean_squared_error: 1.7791
# Epoch 96/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.0464 - y1_output_loss: 0.7603 - y2_output_loss: 2.2702 - y1_output_root_mean_squared_error: 0.8739 - y2_output_root_mean_squared_error: 1.5109 - val_loss: 3.1380 - val_y1_output_loss: 0.5274 - val_y2_output_loss: 2.7742 - val_y1_output_root_mean_squared_error: 0.7330 - val_y2_output_root_mean_squared_error: 1.6127
# Epoch 97/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.6689 - y1_output_loss: 0.6630 - y2_output_loss: 2.0039 - y1_output_root_mean_squared_error: 0.8157 - y2_output_root_mean_squared_error: 1.4154 - val_loss: 3.6790 - val_y1_output_loss: 0.6155 - val_y2_output_loss: 3.2685 - val_y1_output_root_mean_squared_error: 0.7801 - val_y2_output_root_mean_squared_error: 1.7523
# Epoch 98/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.3290 - y1_output_loss: 0.7522 - y2_output_loss: 2.5759 - y1_output_root_mean_squared_error: 0.8699 - y2_output_root_mean_squared_error: 1.6038 - val_loss: 5.8463 - val_y1_output_loss: 2.0479 - val_y2_output_loss: 3.7791 - val_y1_output_root_mean_squared_error: 1.4506 - val_y2_output_root_mean_squared_error: 1.9345
# Epoch 99/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.5504 - y1_output_loss: 0.5768 - y2_output_loss: 1.9847 - y1_output_root_mean_squared_error: 0.7572 - y2_output_root_mean_squared_error: 1.4061 - val_loss: 2.9990 - val_y1_output_loss: 0.5812 - val_y2_output_loss: 2.4656 - val_y1_output_root_mean_squared_error: 0.7645 - val_y2_output_root_mean_squared_error: 1.5539
# Epoch 100/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.5102 - y1_output_loss: 0.5744 - y2_output_loss: 1.9151 - y1_output_root_mean_squared_error: 0.7611 - y2_output_root_mean_squared_error: 1.3896 - val_loss: 2.7173 - val_y1_output_loss: 0.4945 - val_y2_output_loss: 2.3815 - val_y1_output_root_mean_squared_error: 0.6996 - val_y2_output_root_mean_squared_error: 1.4926
# Epoch 101/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.9554 - y1_output_loss: 0.6301 - y2_output_loss: 2.3184 - y1_output_root_mean_squared_error: 0.7951 - y2_output_root_mean_squared_error: 1.5242 - val_loss: 3.2166 - val_y1_output_loss: 0.4462 - val_y2_output_loss: 2.8763 - val_y1_output_root_mean_squared_error: 0.6716 - val_y2_output_root_mean_squared_error: 1.6630
# Epoch 102/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.5926 - y1_output_loss: 0.6303 - y2_output_loss: 1.9510 - y1_output_root_mean_squared_error: 0.7942 - y2_output_root_mean_squared_error: 1.4006 - val_loss: 3.2012 - val_y1_output_loss: 0.6283 - val_y2_output_loss: 2.6949 - val_y1_output_root_mean_squared_error: 0.7959 - val_y2_output_root_mean_squared_error: 1.6024
# Epoch 103/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.4896 - y1_output_loss: 0.5698 - y2_output_loss: 1.9278 - y1_output_root_mean_squared_error: 0.7520 - y2_output_root_mean_squared_error: 1.3871 - val_loss: 7.9750 - val_y1_output_loss: 2.9008 - val_y2_output_loss: 5.0901 - val_y1_output_root_mean_squared_error: 1.7219 - val_y2_output_root_mean_squared_error: 2.2383
# Epoch 104/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.7815 - y1_output_loss: 0.6957 - y2_output_loss: 2.0841 - y1_output_root_mean_squared_error: 0.8336 - y2_output_root_mean_squared_error: 1.4445 - val_loss: 3.5136 - val_y1_output_loss: 0.9995 - val_y2_output_loss: 2.5774 - val_y1_output_root_mean_squared_error: 1.0015 - val_y2_output_root_mean_squared_error: 1.5845
# Epoch 105/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.3729 - y1_output_loss: 0.5525 - y2_output_loss: 1.8072 - y1_output_root_mean_squared_error: 0.7406 - y2_output_root_mean_squared_error: 1.3507 - val_loss: 2.6379 - val_y1_output_loss: 0.5089 - val_y2_output_loss: 2.2197 - val_y1_output_root_mean_squared_error: 0.7139 - val_y2_output_root_mean_squared_error: 1.4588
# Epoch 106/500
# 614/614 [==============================] - 0s 123us/sample - loss: 2.6733 - y1_output_loss: 0.6182 - y2_output_loss: 2.0371 - y1_output_root_mean_squared_error: 0.7880 - y2_output_root_mean_squared_error: 1.4326 - val_loss: 2.7412 - val_y1_output_loss: 0.5468 - val_y2_output_loss: 2.2746 - val_y1_output_root_mean_squared_error: 0.7448 - val_y2_output_root_mean_squared_error: 1.4787
# Epoch 107/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.3498 - y1_output_loss: 0.5863 - y2_output_loss: 1.7532 - y1_output_root_mean_squared_error: 0.7663 - y2_output_root_mean_squared_error: 1.3276 - val_loss: 3.4211 - val_y1_output_loss: 0.5966 - val_y2_output_loss: 2.9616 - val_y1_output_root_mean_squared_error: 0.7714 - val_y2_output_root_mean_squared_error: 1.6811
# Epoch 108/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.1043 - y1_output_loss: 0.4932 - y2_output_loss: 1.6083 - y1_output_root_mean_squared_error: 0.7011 - y2_output_root_mean_squared_error: 1.2700 - val_loss: 4.4231 - val_y1_output_loss: 0.5911 - val_y2_output_loss: 3.9106 - val_y1_output_root_mean_squared_error: 0.7748 - val_y2_output_root_mean_squared_error: 1.9552
# Epoch 109/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.4578 - y1_output_loss: 0.5061 - y2_output_loss: 1.9349 - y1_output_root_mean_squared_error: 0.7105 - y2_output_root_mean_squared_error: 1.3975 - val_loss: 2.3506 - val_y1_output_loss: 0.4000 - val_y2_output_loss: 2.0206 - val_y1_output_root_mean_squared_error: 0.6343 - val_y2_output_root_mean_squared_error: 1.3958
# Epoch 110/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.5722 - y1_output_loss: 0.5491 - y2_output_loss: 2.0331 - y1_output_root_mean_squared_error: 0.7431 - y2_output_root_mean_squared_error: 1.4213 - val_loss: 7.4244 - val_y1_output_loss: 1.6487 - val_y2_output_loss: 5.9030 - val_y1_output_root_mean_squared_error: 1.2879 - val_y2_output_root_mean_squared_error: 2.4012
# Epoch 111/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.2449 - y1_output_loss: 0.4950 - y2_output_loss: 1.7305 - y1_output_root_mean_squared_error: 0.7060 - y2_output_root_mean_squared_error: 1.3215 - val_loss: 2.2695 - val_y1_output_loss: 0.4096 - val_y2_output_loss: 1.8955 - val_y1_output_root_mean_squared_error: 0.6459 - val_y2_output_root_mean_squared_error: 1.3610
# Epoch 112/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.0689 - y1_output_loss: 0.4444 - y2_output_loss: 1.6157 - y1_output_root_mean_squared_error: 0.6659 - y2_output_root_mean_squared_error: 1.2749 - val_loss: 4.6467 - val_y1_output_loss: 0.5119 - val_y2_output_loss: 4.2594 - val_y1_output_root_mean_squared_error: 0.7222 - val_y2_output_root_mean_squared_error: 2.0310
# Epoch 113/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.5379 - y1_output_loss: 0.4955 - y2_output_loss: 2.0245 - y1_output_root_mean_squared_error: 0.7037 - y2_output_root_mean_squared_error: 1.4293 - val_loss: 3.0819 - val_y1_output_loss: 0.5505 - val_y2_output_loss: 2.6125 - val_y1_output_root_mean_squared_error: 0.7468 - val_y2_output_root_mean_squared_error: 1.5888
# Epoch 114/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.1169 - y1_output_loss: 1.4522 - y2_output_loss: 3.6587 - y1_output_root_mean_squared_error: 1.2091 - y2_output_root_mean_squared_error: 1.9118 - val_loss: 5.5384 - val_y1_output_loss: 0.7249 - val_y2_output_loss: 4.8908 - val_y1_output_root_mean_squared_error: 0.8627 - val_y2_output_root_mean_squared_error: 2.1895
# Epoch 115/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.7908 - y1_output_loss: 0.7072 - y2_output_loss: 2.1604 - y1_output_root_mean_squared_error: 0.8393 - y2_output_root_mean_squared_error: 1.4444 - val_loss: 13.6080 - val_y1_output_loss: 3.0580 - val_y2_output_loss: 10.5626 - val_y1_output_root_mean_squared_error: 1.7501 - val_y2_output_root_mean_squared_error: 3.2473
# Epoch 116/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.5428 - y1_output_loss: 0.5257 - y2_output_loss: 2.0096 - y1_output_root_mean_squared_error: 0.7199 - y2_output_root_mean_squared_error: 1.4229 - val_loss: 3.5589 - val_y1_output_loss: 0.6602 - val_y2_output_loss: 2.9666 - val_y1_output_root_mean_squared_error: 0.8170 - val_y2_output_root_mean_squared_error: 1.7004
# Epoch 117/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.0991 - y1_output_loss: 1.0517 - y2_output_loss: 3.0154 - y1_output_root_mean_squared_error: 1.0304 - y2_output_root_mean_squared_error: 1.7428 - val_loss: 3.9999 - val_y1_output_loss: 0.6320 - val_y2_output_loss: 3.4764 - val_y1_output_root_mean_squared_error: 0.7973 - val_y2_output_root_mean_squared_error: 1.8342
# Epoch 118/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.0606 - y1_output_loss: 0.4318 - y2_output_loss: 1.6103 - y1_output_root_mean_squared_error: 0.6597 - y2_output_root_mean_squared_error: 1.2749 - val_loss: 2.2391 - val_y1_output_loss: 0.4057 - val_y2_output_loss: 1.8909 - val_y1_output_root_mean_squared_error: 0.6408 - val_y2_output_root_mean_squared_error: 1.3522
# Epoch 119/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.1754 - y1_output_loss: 0.4811 - y2_output_loss: 1.6860 - y1_output_root_mean_squared_error: 0.6967 - y2_output_root_mean_squared_error: 1.3000 - val_loss: 2.4172 - val_y1_output_loss: 0.5987 - val_y2_output_loss: 1.8784 - val_y1_output_root_mean_squared_error: 0.7743 - val_y2_output_root_mean_squared_error: 1.3482
# Epoch 120/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.0078 - y1_output_loss: 0.4642 - y2_output_loss: 1.5697 - y1_output_root_mean_squared_error: 0.6656 - y2_output_root_mean_squared_error: 1.2509 - val_loss: 4.0552 - val_y1_output_loss: 1.4124 - val_y2_output_loss: 2.5971 - val_y1_output_root_mean_squared_error: 1.2014 - val_y2_output_root_mean_squared_error: 1.6161
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4962 - y1_output_loss: 0.1315 - y2_output_loss: 0.3712 - y1_output_root_mean_squared_error: 0.3622 - y2_output_root_mean_squared_error: 0.6042 - val_loss: 1.1897 - val_y1_output_loss: 0.2511 - val_y2_output_loss: 0.9255 - val_y1_output_root_mean_squared_error: 0.5052 - val_y2_output_root_mean_squared_error: 0.9667
# Epoch 462/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.5028 - y1_output_loss: 0.1420 - y2_output_loss: 0.3608 - y1_output_root_mean_squared_error: 0.3751 - y2_output_root_mean_squared_error: 0.6018 - val_loss: 0.8909 - val_y1_output_loss: 0.2379 - val_y2_output_loss: 0.6354 - val_y1_output_root_mean_squared_error: 0.4903 - val_y2_output_root_mean_squared_error: 0.8066
# Epoch 463/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4735 - y1_output_loss: 0.1525 - y2_output_loss: 0.3190 - y1_output_root_mean_squared_error: 0.3897 - y2_output_root_mean_squared_error: 0.5671 - val_loss: 0.9556 - val_y1_output_loss: 0.2723 - val_y2_output_loss: 0.6686 - val_y1_output_root_mean_squared_error: 0.5224 - val_y2_output_root_mean_squared_error: 0.8262
# Epoch 464/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3818 - y1_output_loss: 0.1155 - y2_output_loss: 0.2712 - y1_output_root_mean_squared_error: 0.3395 - y2_output_root_mean_squared_error: 0.5163 - val_loss: 0.9891 - val_y1_output_loss: 0.2810 - val_y2_output_loss: 0.6891 - val_y1_output_root_mean_squared_error: 0.5353 - val_y2_output_root_mean_squared_error: 0.8382
# Epoch 465/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3770 - y1_output_loss: 0.1151 - y2_output_loss: 0.2598 - y1_output_root_mean_squared_error: 0.3405 - y2_output_root_mean_squared_error: 0.5110 - val_loss: 0.9266 - val_y1_output_loss: 0.2463 - val_y2_output_loss: 0.6739 - val_y1_output_root_mean_squared_error: 0.4943 - val_y2_output_root_mean_squared_error: 0.8260
# Epoch 466/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4065 - y1_output_loss: 0.1250 - y2_output_loss: 0.2826 - y1_output_root_mean_squared_error: 0.3537 - y2_output_root_mean_squared_error: 0.5305 - val_loss: 1.2312 - val_y1_output_loss: 0.2781 - val_y2_output_loss: 0.9423 - val_y1_output_root_mean_squared_error: 0.5253 - val_y2_output_root_mean_squared_error: 0.9774
# Epoch 467/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4406 - y1_output_loss: 0.1432 - y2_output_loss: 0.2976 - y1_output_root_mean_squared_error: 0.3800 - y2_output_root_mean_squared_error: 0.5442 - val_loss: 1.1147 - val_y1_output_loss: 0.2518 - val_y2_output_loss: 0.8637 - val_y1_output_root_mean_squared_error: 0.4988 - val_y2_output_root_mean_squared_error: 0.9305
# Epoch 468/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3873 - y1_output_loss: 0.1279 - y2_output_loss: 0.2562 - y1_output_root_mean_squared_error: 0.3590 - y2_output_root_mean_squared_error: 0.5083 - val_loss: 0.9045 - val_y1_output_loss: 0.2466 - val_y2_output_loss: 0.6461 - val_y1_output_root_mean_squared_error: 0.4976 - val_y2_output_root_mean_squared_error: 0.8105
# Epoch 469/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4515 - y1_output_loss: 0.1283 - y2_output_loss: 0.3199 - y1_output_root_mean_squared_error: 0.3591 - y2_output_root_mean_squared_error: 0.5679 - val_loss: 1.0850 - val_y1_output_loss: 0.2394 - val_y2_output_loss: 0.8380 - val_y1_output_root_mean_squared_error: 0.4875 - val_y2_output_root_mean_squared_error: 0.9205
# Epoch 470/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.5360 - y1_output_loss: 0.1584 - y2_output_loss: 0.3849 - y1_output_root_mean_squared_error: 0.3875 - y2_output_root_mean_squared_error: 0.6212 - val_loss: 1.7873 - val_y1_output_loss: 0.5330 - val_y2_output_loss: 1.2179 - val_y1_output_root_mean_squared_error: 0.7368 - val_y2_output_root_mean_squared_error: 1.1155
# Epoch 471/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3881 - y1_output_loss: 0.1215 - y2_output_loss: 0.2670 - y1_output_root_mean_squared_error: 0.3489 - y2_output_root_mean_squared_error: 0.5162 - val_loss: 1.4265 - val_y1_output_loss: 0.2697 - val_y2_output_loss: 1.1542 - val_y1_output_root_mean_squared_error: 0.5267 - val_y2_output_root_mean_squared_error: 1.0719
# Epoch 472/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4356 - y1_output_loss: 0.1392 - y2_output_loss: 0.2942 - y1_output_root_mean_squared_error: 0.3738 - y2_output_root_mean_squared_error: 0.5439 - val_loss: 0.8841 - val_y1_output_loss: 0.2356 - val_y2_output_loss: 0.6306 - val_y1_output_root_mean_squared_error: 0.4856 - val_y2_output_root_mean_squared_error: 0.8052
# Epoch 473/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4495 - y1_output_loss: 0.1310 - y2_output_loss: 0.3152 - y1_output_root_mean_squared_error: 0.3632 - y2_output_root_mean_squared_error: 0.5635 - val_loss: 0.8656 - val_y1_output_loss: 0.2226 - val_y2_output_loss: 0.6233 - val_y1_output_root_mean_squared_error: 0.4733 - val_y2_output_root_mean_squared_error: 0.8010
# Epoch 474/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4112 - y1_output_loss: 0.1174 - y2_output_loss: 0.2920 - y1_output_root_mean_squared_error: 0.3431 - y2_output_root_mean_squared_error: 0.5417 - val_loss: 1.0558 - val_y1_output_loss: 0.2167 - val_y2_output_loss: 0.8263 - val_y1_output_root_mean_squared_error: 0.4679 - val_y2_output_root_mean_squared_error: 0.9148
# Epoch 475/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3467 - y1_output_loss: 0.1244 - y2_output_loss: 0.2211 - y1_output_root_mean_squared_error: 0.3536 - y2_output_root_mean_squared_error: 0.4708 - val_loss: 1.0351 - val_y1_output_loss: 0.2715 - val_y2_output_loss: 0.7384 - val_y1_output_root_mean_squared_error: 0.5289 - val_y2_output_root_mean_squared_error: 0.8691
# Epoch 476/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4599 - y1_output_loss: 0.1484 - y2_output_loss: 0.3218 - y1_output_root_mean_squared_error: 0.3773 - y2_output_root_mean_squared_error: 0.5635 - val_loss: 2.0356 - val_y1_output_loss: 0.5568 - val_y2_output_loss: 1.4345 - val_y1_output_root_mean_squared_error: 0.7586 - val_y2_output_root_mean_squared_error: 1.2084
# Epoch 477/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.5081 - y1_output_loss: 0.1583 - y2_output_loss: 0.3517 - y1_output_root_mean_squared_error: 0.3958 - y2_output_root_mean_squared_error: 0.5929 - val_loss: 1.8215 - val_y1_output_loss: 0.4696 - val_y2_output_loss: 1.3057 - val_y1_output_root_mean_squared_error: 0.6922 - val_y2_output_root_mean_squared_error: 1.1586
# Epoch 478/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4207 - y1_output_loss: 0.1385 - y2_output_loss: 0.2795 - y1_output_root_mean_squared_error: 0.3737 - y2_output_root_mean_squared_error: 0.5301 - val_loss: 0.8972 - val_y1_output_loss: 0.2350 - val_y2_output_loss: 0.6527 - val_y1_output_root_mean_squared_error: 0.4851 - val_y2_output_root_mean_squared_error: 0.8135
# Epoch 479/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5954 - y1_output_loss: 0.1804 - y2_output_loss: 0.4098 - y1_output_root_mean_squared_error: 0.4266 - y2_output_root_mean_squared_error: 0.6429 - val_loss: 0.8698 - val_y1_output_loss: 0.2156 - val_y2_output_loss: 0.6301 - val_y1_output_root_mean_squared_error: 0.4707 - val_y2_output_root_mean_squared_error: 0.8051
# Epoch 480/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4012 - y1_output_loss: 0.1296 - y2_output_loss: 0.2689 - y1_output_root_mean_squared_error: 0.3608 - y2_output_root_mean_squared_error: 0.5206 - val_loss: 0.8760 - val_y1_output_loss: 0.2171 - val_y2_output_loss: 0.6407 - val_y1_output_root_mean_squared_error: 0.4683 - val_y2_output_root_mean_squared_error: 0.8104
# Epoch 481/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5275 - y1_output_loss: 0.1813 - y2_output_loss: 0.3463 - y1_output_root_mean_squared_error: 0.4238 - y2_output_root_mean_squared_error: 0.5899 - val_loss: 1.2422 - val_y1_output_loss: 0.2665 - val_y2_output_loss: 0.9522 - val_y1_output_root_mean_squared_error: 0.5213 - val_y2_output_root_mean_squared_error: 0.9851
# Epoch 482/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4798 - y1_output_loss: 0.1468 - y2_output_loss: 0.3337 - y1_output_root_mean_squared_error: 0.3841 - y2_output_root_mean_squared_error: 0.5764 - val_loss: 1.4950 - val_y1_output_loss: 0.2951 - val_y2_output_loss: 1.2207 - val_y1_output_root_mean_squared_error: 0.5408 - val_y2_output_root_mean_squared_error: 1.0966
# Epoch 483/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4270 - y1_output_loss: 0.1356 - y2_output_loss: 0.2905 - y1_output_root_mean_squared_error: 0.3670 - y2_output_root_mean_squared_error: 0.5406 - val_loss: 0.9750 - val_y1_output_loss: 0.2513 - val_y2_output_loss: 0.7054 - val_y1_output_root_mean_squared_error: 0.5019 - val_y2_output_root_mean_squared_error: 0.8504
# Epoch 484/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3823 - y1_output_loss: 0.1351 - y2_output_loss: 0.2498 - y1_output_root_mean_squared_error: 0.3634 - y2_output_root_mean_squared_error: 0.5003 - val_loss: 0.8754 - val_y1_output_loss: 0.2464 - val_y2_output_loss: 0.6101 - val_y1_output_root_mean_squared_error: 0.4953 - val_y2_output_root_mean_squared_error: 0.7937
# Epoch 485/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4712 - y1_output_loss: 0.1358 - y2_output_loss: 0.3325 - y1_output_root_mean_squared_error: 0.3686 - y2_output_root_mean_squared_error: 0.5791 - val_loss: 0.8851 - val_y1_output_loss: 0.2518 - val_y2_output_loss: 0.6119 - val_y1_output_root_mean_squared_error: 0.5049 - val_y2_output_root_mean_squared_error: 0.7938
# Epoch 486/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3662 - y1_output_loss: 0.1193 - y2_output_loss: 0.2489 - y1_output_root_mean_squared_error: 0.3453 - y2_output_root_mean_squared_error: 0.4970 - val_loss: 1.9544 - val_y1_output_loss: 0.4683 - val_y2_output_loss: 1.4797 - val_y1_output_root_mean_squared_error: 0.6784 - val_y2_output_root_mean_squared_error: 1.2224
# Epoch 487/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4242 - y1_output_loss: 0.1341 - y2_output_loss: 0.2882 - y1_output_root_mean_squared_error: 0.3672 - y2_output_root_mean_squared_error: 0.5380 - val_loss: 1.0242 - val_y1_output_loss: 0.2744 - val_y2_output_loss: 0.7334 - val_y1_output_root_mean_squared_error: 0.5295 - val_y2_output_root_mean_squared_error: 0.8624
# Epoch 488/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4207 - y1_output_loss: 0.1393 - y2_output_loss: 0.3303 - y1_output_root_mean_squared_error: 0.3673 - y2_output_root_mean_squared_error: 0.5346 - val_loss: 17.1143 - val_y1_output_loss: 2.2460 - val_y2_output_loss: 15.1201 - val_y1_output_root_mean_squared_error: 1.5141 - val_y2_output_root_mean_squared_error: 3.8499
# Epoch 489/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.5625 - y1_output_loss: 1.0781 - y2_output_loss: 3.4593 - y1_output_root_mean_squared_error: 1.0431 - y2_output_root_mean_squared_error: 1.8640 - val_loss: 1.2073 - val_y1_output_loss: 0.2416 - val_y2_output_loss: 0.9571 - val_y1_output_root_mean_squared_error: 0.4908 - val_y2_output_root_mean_squared_error: 0.9831
# Epoch 490/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4904 - y1_output_loss: 0.1292 - y2_output_loss: 0.3580 - y1_output_root_mean_squared_error: 0.3597 - y2_output_root_mean_squared_error: 0.6008 - val_loss: 1.0245 - val_y1_output_loss: 0.2173 - val_y2_output_loss: 0.8013 - val_y1_output_root_mean_squared_error: 0.4662 - val_y2_output_root_mean_squared_error: 0.8984
# Epoch 491/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3334 - y1_output_loss: 0.1206 - y2_output_loss: 0.2156 - y1_output_root_mean_squared_error: 0.3481 - y2_output_root_mean_squared_error: 0.4606 - val_loss: 1.4066 - val_y1_output_loss: 0.2809 - val_y2_output_loss: 1.1185 - val_y1_output_root_mean_squared_error: 0.5268 - val_y2_output_root_mean_squared_error: 1.0626
# Epoch 492/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4565 - y1_output_loss: 0.1442 - y2_output_loss: 0.3112 - y1_output_root_mean_squared_error: 0.3811 - y2_output_root_mean_squared_error: 0.5579 - val_loss: 1.0299 - val_y1_output_loss: 0.2106 - val_y2_output_loss: 0.8093 - val_y1_output_root_mean_squared_error: 0.4589 - val_y2_output_root_mean_squared_error: 0.9051
# Epoch 493/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3347 - y1_output_loss: 0.1169 - y2_output_loss: 0.2173 - y1_output_root_mean_squared_error: 0.3413 - y2_output_root_mean_squared_error: 0.4671 - val_loss: 0.9847 - val_y1_output_loss: 0.2777 - val_y2_output_loss: 0.6812 - val_y1_output_root_mean_squared_error: 0.5349 - val_y2_output_root_mean_squared_error: 0.8359
# Epoch 494/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3804 - y1_output_loss: 0.1205 - y2_output_loss: 0.2575 - y1_output_root_mean_squared_error: 0.3483 - y2_output_root_mean_squared_error: 0.5090 - val_loss: 0.9434 - val_y1_output_loss: 0.2673 - val_y2_output_loss: 0.6534 - val_y1_output_root_mean_squared_error: 0.5204 - val_y2_output_root_mean_squared_error: 0.8201
# Epoch 495/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3752 - y1_output_loss: 0.1162 - y2_output_loss: 0.2564 - y1_output_root_mean_squared_error: 0.3419 - y2_output_root_mean_squared_error: 0.5083 - val_loss: 0.9338 - val_y1_output_loss: 0.2568 - val_y2_output_loss: 0.6597 - val_y1_output_root_mean_squared_error: 0.5083 - val_y2_output_root_mean_squared_error: 0.8218
# Epoch 496/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.7508 - y1_output_loss: 0.1796 - y2_output_loss: 0.5649 - y1_output_root_mean_squared_error: 0.4255 - y2_output_root_mean_squared_error: 0.7548 - val_loss: 0.9784 - val_y1_output_loss: 0.2164 - val_y2_output_loss: 0.7511 - val_y1_output_root_mean_squared_error: 0.4676 - val_y2_output_root_mean_squared_error: 0.8716
# Epoch 497/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3347 - y1_output_loss: 0.1094 - y2_output_loss: 0.2274 - y1_output_root_mean_squared_error: 0.3316 - y2_output_root_mean_squared_error: 0.4741 - val_loss: 1.2135 - val_y1_output_loss: 0.3341 - val_y2_output_loss: 0.8586 - val_y1_output_root_mean_squared_error: 0.5864 - val_y2_output_root_mean_squared_error: 0.9326
# Epoch 498/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3817 - y1_output_loss: 0.1272 - y2_output_loss: 0.2542 - y1_output_root_mean_squared_error: 0.3552 - y2_output_root_mean_squared_error: 0.5055 - val_loss: 0.9901 - val_y1_output_loss: 0.2788 - val_y2_output_loss: 0.6903 - val_y1_output_root_mean_squared_error: 0.5340 - val_y2_output_root_mean_squared_error: 0.8396
# Epoch 499/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3512 - y1_output_loss: 0.1243 - y2_output_loss: 0.2261 - y1_output_root_mean_squared_error: 0.3519 - y2_output_root_mean_squared_error: 0.4768 - val_loss: 0.8588 - val_y1_output_loss: 0.2580 - val_y2_output_loss: 0.5836 - val_y1_output_root_mean_squared_error: 0.5062 - val_y2_output_root_mean_squared_error: 0.7762
# Epoch 500/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4466 - y1_output_loss: 0.1496 - y2_output_loss: 0.2994 - y1_output_root_mean_squared_error: 0.3809 - y2_output_root_mean_squared_error: 0.5491 - val_loss: 1.1774 - val_y1_output_loss: 0.4149 - val_y2_output_loss: 0.7355 - val_y1_output_root_mean_squared_error: 0.6527 - val_y2_output_root_mean_squared_error: 0.8668

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 33us/sample - loss: 1.1774 - y1_output_loss: 0.4207 - y2_output_loss: 0.7450 - y1_output_root_mean_squared_error: 0.6527 - y2_output_root_mean_squared_error: 0.8668
# Loss = 1.1773962014681334, Y1_loss = 0.4206980764865875, Y1_mse = 0.6526708006858826, Y2_loss = 0.7449657320976257, Y2_mse = 0.8668431043624878

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
